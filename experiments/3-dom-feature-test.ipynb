# %% [markdown]
# ## Dom feature test
# This document serves as a sanity check for the implementation of the DOM feature extractor

# %%
# %matplotlib inline

import sys, os

# pandas
import pandas as pd

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# add the library path
sys.path.append(os.path.join(os.getcwd(), "src"))
from features import extract_features_from_html

# this styling is purely my preference
# less chartjunk
sns.set_context('notebook', font_scale=1.5, rc={'line.linewidth': 2.5})
sns.set(style='ticks', palette='Set2')

# %%
# load the data
df = pd.read_csv('../data/2017-07-21-13:41:49-ecommerce-ro.csv')
df.head()
# Out:
#                                                 html  \
# 0  <!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <...
# 1  <!DOCTYPE html>\n<html>\n  <head>\n    <link r...
# 2  <!DOCTYPE html>\n<html>\n  <head>\n    <link r...
# 3  <!DOCTYPE html>\n<html>\n  <head>\n    <link r...
# 4  <!DOCTYPE html>\n<html>\n  <head>\n    <link r...
#
#                                                  url
# 0                                    https://brx.ro/
# 1                        https://brx.ro/adauga-anunt
# 2  https://brx.ro/anunturi/categorie/auto-moto-si...
# 3       https://brx.ro/anunturi/categorie/imobiliare
# 4  https://brx.ro/anunturi/categorie/electronice-...

# %%
# try extracting features 
feats = extract_features_from_html(df.html[0], 2, 2)
feats.iloc[100:105]
# Out:
#      depth      tag  no_classes  has_id  no_children  has_text  \
# 100      8        a           0   False            2     False
# 101      9      div           1   False            1     False
# 102     10      img           1   False            0     False
# 103      9     span           1   False            0      True
# 104      7  comment           0   False            0      True
#
#               classes  descendant1_no_nodes  descendant1_no_children_avg  \
# 100                []                     2                          0.5
# 101   [category-icon]                     1                          0.0
# 102  [img-responsive]                     0                          0.0
# 103  [category-title]                     0                          0.0
# 104                []                     0                          0.0
#
#      descendant1_has_id_avg               ...                \
# 100                     0.0               ...
# 101                     0.0               ...
# 102                     0.0               ...
# 103                     0.0               ...
# 104                     0.0               ...
#
#      ancestor1_no_children  ancestor1_has_text       ancestor1_classes  \
# 100                      1               False         [category-item]
# 101                      2               False                      []
# 102                      1               False         [category-icon]
# 103                      2               False                      []
# 104                     20               False  [left, homecategories]
#
#     ancestor2_depth  ancestor2_tag  ancestor2_no_classes  ancestor2_has_id  \
# 100               6            div                     2             False
# 101               7             li                     1             False
# 102               8              a                     0             False
# 103               7             li                     1             False
# 104               5            div                     3             False
#
#      ancestor2_no_children  ancestor2_has_text               ancestor2_classes
# 100                     20               False          [left, homecategories]
# 101                      1               False                 [category-item]
# 102                      2               False                              []
# 103                      1               False                 [category-item]
# 104                      5               False  [container_12, clearfix, home]
#
# [5 rows x 35 columns]

# %%
# ancestor features
ancestor_feats = feats.filter(like='ancestor', axis='columns')
ancestor_feats.tail()
# Out:
#      ancestor1_depth ancestor1_tag  ancestor1_no_classes  ancestor1_has_id  \
# 246                6             p                     0             False
# 247                5           div                     1             False
# 248                4           div                     2             False
# 249                4           div                     2             False
# 250                2          body                     1             False
#
#      ancestor1_no_children  ancestor1_has_text  ancestor1_classes  \
# 246                      1               False                 []
# 247                      4               False             [form]
# 248                      5               False  [envelope, popup]
# 249                      5               False  [envelope, popup]
# 250                      9               False         [homepage]
#
#      ancestor2_depth ancestor2_tag  ancestor2_no_classes  ancestor2_has_id  \
# 246                5           div                     1             False
# 247                4           div                     2             False
# 248                3           div                     2             False
# 249                3           div                     2             False
# 250                1          html                     0             False
#
#      ancestor2_no_children  ancestor2_has_text          ancestor2_classes
# 246                      4               False                     [form]
# 247                      5               False          [envelope, popup]
# 248                      2               False  [invisible, facebookLike]
# 249                      2               False  [invisible, facebookLike]
# 250                      2               False                         []

# %%
# descendant features
descendant_feats = feats.filter(like='descendant', axis='columns')
descendant_feats.head()
# Out:
#    descendant1_no_nodes  descendant1_no_children_avg  descendant1_has_id_avg  \
# 0                     2                         19.5                     0.0
# 1                    30                          0.0                     0.2
# 2                     0                          0.0                     0.0
# 3                     0                          0.0                     0.0
# 4                     0                          0.0                     0.0
#
#    descendant1_no_classes_avg  descendant1_has_text_avg descendant1_classes  \
# 0                         0.5                  0.000000          [homepage]
# 1                         0.0                  0.166667                  []
# 2                         0.0                  0.000000                  []
# 3                         0.0                  0.000000                  []
# 4                         0.0                  0.000000                  []
#
#                                     descendant1_tags  descendant2_no_nodes  \
# 0                                       [head, body]                    39
# 1  [link, meta, title, meta, comment, link, link,...                     0
# 2                                                 []                     0
# 3                                                 []                     0
# 4                                                 []                     0
#
#    descendant2_no_children_avg  descendant2_has_id_avg  \
# 0                     0.179487                0.153846
# 1                     0.000000                0.000000
# 2                     0.000000                0.000000
# 3                     0.000000                0.000000
# 4                     0.000000                0.000000
#
#    descendant2_no_classes_avg  descendant2_has_text_avg  \
# 0                    0.153846                  0.230769
# 1                    0.000000                  0.000000
# 2                    0.000000                  0.000000
# 3                    0.000000                  0.000000
# 4                    0.000000                  0.000000
#
#                                  descendant2_classes  \
# 0  [standardwidth, home, standardwidth, loader, i...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                     descendant2_tags
# 0  [link, meta, title, meta, comment, link, link,...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []

# %%
# normal features
non_node_feats = list(descendant_feats.columns) + list(ancestor_feats.columns)
node_feats = feats.drop(non_node_feats, axis='columns')
node_feats.iloc[100:105]
# Out:
#      depth      tag  no_classes  has_id  no_children  has_text  \
# 100      8        a           0   False            2     False
# 101      9      div           1   False            1     False
# 102     10      img           1   False            0     False
# 103      9     span           1   False            0      True
# 104      7  comment           0   False            0      True
#
#               classes
# 100                []
# 101   [category-icon]
# 102  [img-responsive]
# 103  [category-title]
# 104                []
