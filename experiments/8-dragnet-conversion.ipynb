# %% [markdown]
# # Dragnet Conversion
# In this notebook we will be fetching the Dragnet data and converting it to our CSV format. We will also be outputting the labels alongside in a `url/path` format as used before. It being a binary classification problem, we will only have one class.
#
# ## Fetching the data
# This step is pretty straightforward, as the seomoz guys have hosted the data on their github and we basically just have to clone it and untar an archive.

# %%
# %%bash
# cd ../data/external/
#
# # clone and untar
# git clone https://github.com/seomoz/dragnet_data.git
# cd dragnet_data
# tar xvf dragnet_HTML.tar.gz
# tar xvf dragnet_Corrected.tar.gz
#
# # copy the cetr data as well
# wget https://www3.nd.edu/~tweninge/cetr/cetr-dataset.zip
# unzip cetr-dataset.zip -d cetr-dataset
# chmod +x cetr_to_dragnet.sh
# ./cetr_to_dragnet.sh cetr-dataset > /dev/null
#
# # move it to the other directory and remove the junk
# cd ..
# mkdir dragnet
# mkdir cleaneval
# mv -t dragnet dragnet_data/{HTML,Corrected}
# mv -t cleaneval dragnet_data/cetr-dataset/cleaneval/en/{Corrected,HTML}
#
# rm -r dragnet_data
# Out:
# HTML/
# HTML/._.DS_Store
# HTML/.DS_Store
# HTML/100.html
# HTML/102.html
# HTML/103.html
# HTML/106.html
# HTML/108.html
# HTML/109.html
# HTML/110.html
# HTML/113.html
# HTML/116.html
# HTML/117.html
# HTML/119.html
# HTML/120.html
# HTML/128.html
# HTML/131.html
# HTML/134.html
# HTML/135.html
# HTML/137.html
# HTML/14.html
# HTML/140.html
# HTML/141.html
# HTML/142.html
# HTML/143.html
# HTML/145.html
# HTML/147.html
# HTML/149.html
# HTML/15.html
# HTML/151.html
# HTML/152.html
# HTML/153.html
# HTML/158.html
# HTML/160.html
# HTML/161.html
# HTML/167.html
# HTML/168.html
# HTML/170.html
# HTML/172.html
# HTML/175.html
# HTML/176.html
# HTML/186.html
# HTML/188.html
# HTML/19.html
# HTML/190.html
# HTML/191.html
# HTML/192.html
# HTML/196.html
# HTML/198.html
# HTML/199.html
# HTML/20.html
# HTML/201.html
# HTML/205.html
# HTML/210.html
# HTML/212.html
# HTML/217.html
# HTML/220.html
# HTML/222.html
# HTML/223.html
# HTML/227.html
# HTML/230.html
# HTML/232.html
# HTML/233.html
# HTML/236.html
# HTML/238.html
# HTML/239.html
# HTML/242.html
# HTML/244.html
# HTML/248.html
# HTML/250.html
# HTML/252.html
# HTML/257.html
# HTML/259.html
# HTML/261.html
# HTML/267.html
# HTML/268.html
# HTML/269.html
# HTML/27.html
# HTML/271.html
# HTML/272.html
# HTML/273.html
# HTML/275.html
# HTML/28.html
# HTML/281.html
# HTML/29.html
# HTML/292.html
# HTML/294.html
# HTML/295.html
# HTML/296.html
# HTML/30.html
# HTML/302.html
# HTML/304.html
# HTML/306.html
# HTML/312.html
# HTML/313.html
# HTML/317.html
# HTML/319.html
# HTML/320.html
# HTML/321.html
# HTML/325.html
# HTML/327.html
# HTML/328.html
# HTML/329.html
# HTML/330.html
# HTML/332.html
# HTML/333.html
# HTML/342.html
# HTML/343.html
# HTML/344.html
# HTML/346.html
# HTML/348.html
# HTML/T6.html
# HTML/T60.html
# HTML/T61.html
# HTML/T62.html
# HTML/T63.html
# HTML/T64.html
# HTML/T65.html
# HTML/T66.html
# HTML/T67.html
# HTML/T68.html
# HTML/T69.html
# HTML/T7.html
# HTML/T70.html
# HTML/T71.html
# HTML/T72.html
# HTML/T73.html
# HTML/T74.html
# HTML/T75.html
# HTML/T76.html
# HTML/T77.html
# HTML/T78.html
# HTML/T79.html
# HTML/T8.html
# HTML/T80.html
# HTML/T81.html
# HTML/T82.html
# HTML/T83.html
# HTML/T84.html
# HTML/T85.html
# HTML/T86.html
# HTML/T87.html
# HTML/T88.html
# HTML/T89.html
# HTML/T9.html
# HTML/T90.html
# HTML/T91.html
# HTML/T92.html
# HTML/T93.html
# HTML/T94.html
# HTML/T95.html
# HTML/T96.html
# HTML/T97.html
# HTML/T98.html
# HTML/T99.html
# Corrected/
# Corrected/100.html.corrected.txt
# Corrected/102.html.corrected.txt
# Corrected/103.html.corrected.txt
# Corrected/106.html.corrected.txt
# Corrected/108.html.corrected.txt
# Corrected/109.html.corrected.txt
# Corrected/110.html.corrected.txt
# Corrected/113.html.corrected.txt
# Corrected/116.html.corrected.txt
# Corrected/117.html.corrected.txt
# Corrected/119.html.corrected.txt
# Corrected/120.html.corrected.txt
# Corrected/128.html.corrected.txt
# Corrected/131.html.corrected.txt
# Corrected/134.html.corrected.txt
# Corrected/135.html.corrected.txt
# Corrected/137.html.corrected.txt
# Corrected/14.html.corrected.txt
# Corrected/140.html.corrected.txt
# Corrected/141.html.corrected.txt
# Corrected/142.html.corrected.txt
# Corrected/143.html.corrected.txt
# Corrected/145.html.corrected.txt
# Corrected/147.html.corrected.txt
# Corrected/149.html.corrected.txt
# Corrected/15.html.corrected.txt
# Corrected/151.html.corrected.txt
# Corrected/152.html.corrected.txt
# Corrected/153.html.corrected.txt
# Corrected/158.html.corrected.txt
# Corrected/160.html.corrected.txt
# Corrected/161.html.corrected.txt
# Corrected/167.html.corrected.txt
# Corrected/168.html.corrected.txt
# Corrected/170.html.corrected.txt
# Corrected/172.html.corrected.txt
# Corrected/175.html.corrected.txt
# Corrected/176.html.corrected.txt
# Corrected/186.html.corrected.txt
# Corrected/188.html.corrected.txt
# Corrected/19.html.corrected.txt
# Corrected/190.html.corrected.txt
# Corrected/191.html.corrected.txt
# Corrected/192.html.corrected.txt
# Corrected/196.html.corrected.txt
# Corrected/198.html.corrected.txt
# Corrected/199.html.corrected.txt
# Corrected/20.html.corrected.txt
# Corrected/201.html.corrected.txt
# Corrected/205.html.corrected.txt
# Corrected/210.html.corrected.txt
# Corrected/212.html.corrected.txt
# Corrected/217.html.corrected.txt
# Corrected/220.html.corrected.txt
# Corrected/222.html.corrected.txt
# Corrected/223.html.corrected.txt
# Corrected/227.html.corrected.txt
# Corrected/230.html.corrected.txt
# Corrected/232.html.corrected.txt
# Corrected/233.html.corrected.txt
# Corrected/236.html.corrected.txt
# Corrected/238.html.corrected.txt
# Corrected/239.html.corrected.txt
# Corrected/242.html.corrected.txt
# Corrected/244.html.corrected.txt
# Corrected/248.html.corrected.txt
# Corrected/250.html.corrected.txt
# Corrected/252.html.corrected.txt
# Corrected/257.html.corrected.txt
# Corrected/259.html.corrected.txt
# Corrected/261.html.corrected.txt
# Corrected/267.html.corrected.txt
# Corrected/268.html.corrected.txt
# Corrected/269.html.corrected.txt
# Corrected/27.html.corrected.txt
# Corrected/271.html.corrected.txt
# Corrected/272.html.corrected.txt
# Corrected/273.html.corrected.txt
# Corrected/275.html.corrected.txt
# Corrected/28.html.corrected.txt
# Corrected/281.html.corrected.txt
# Corrected/29.html.corrected.txt
# Corrected/292.html.corrected.txt
# Corrected/294.html.corrected.txt
# Corrected/295.html.corrected.txt
# Corrected/296.html.corrected.txt
# Corrected/30.html.corrected.txt
# Corrected/302.html.corrected.txt
# Corrected/304.html.corrected.txt
# Corrected/306.html.corrected.txt
# Corrected/312.html.corrected.txt
# Corrected/313.html.corrected.txt
# Corrected/317.html.corrected.txt
# Corrected/319.html.corrected.txt
# Corrected/320.html.corrected.txt
# Corrected/321.html.corrected.txt
# Corrected/325.html.corrected.txt
# Corrected/327.html.corrected.txt
# Corrected/328.html.corrected.txt
# Corrected/329.html.corrected.txt
# Corrected/330.html.corrected.txt
# Corrected/332.html.corrected.txt
# Corrected/333.html.corrected.txt
# Corrected/342.html.corrected.txt
# Corrected/343.html.corrected.txt
# Corrected/344.html.corrected.txt
# Corrected/346.html.corrected.txt
# Corrected/348.html.corrected.txt
# Corrected/349.html.corrected.txt
# Corrected/35.html.corrected.txt
# Corrected/352.html.corrected.txt
# Corrected/355.html.corrected.txt
# Corrected/356.html.corrected.txt
# Corrected/357.html.corrected.txt
# Corrected/358.html.corrected.txt
# Corrected/360.html.corrected.txt
# Corrected/361.html.corrected.txt
# Corrected/366.html.corrected.txt
# Corrected/368.html.corrected.txt
# Corrected/369.html.corrected.txt
# Corrected/370.html.corrected.txt
# Corrected/375.html.corrected.txt
# Corrected/380.html.corrected.txt
# Corrected/382.html.corrected.txt
# Corrected/383.html.corrected.txt
# Corrected/386.html.corrected.txt
# Corrected/39.html.corrected.txt
# Corrected/391.html.corrected.txt
# Corrected/393.html.corrected.txt
# Corrected/395.html.corrected.txt
# Corrected/408.html.corrected.txt
# Corrected/409.html.corrected.txt
# Corrected/41.html.corrected.txt
# Corrected/415.html.corrected.txt
# Corrected/416.html.corrected.txt
# Corrected/418.html.corrected.txt
# Corrected/419.html.corrected.txt
# Corrected/42.html.corrected.txt
# Corrected/422.html.corrected.txt
# Corrected/424.html.corrected.txt
# Corrected/425.html.corrected.txt
# Corrected/429.html.corrected.txt
# Corrected/431.html.corrected.txt
# Corrected/434.html.corrected.txt
# Corrected/437.html.corrected.txt
# Corrected/438.html.corrected.txt
# Corrected/439.html.corrected.txt
# Corrected/44.html.corrected.txt
# Corrected/441.html.corrected.txt
# Corrected/445.html.corrected.txt
# Corrected/452.html.corrected.txt
# Corrected/453.html.corrected.txt
# Corrected/455.html.corrected.txt
# Corrected/456.html.corrected.txt
# Corrected/458.html.corrected.txt
# Corrected/459.html.corrected.txt
# Corrected/460.html.corrected.txt
# Corrected/468.html.corrected.txt
# Corrected/470.html.corrected.txt
# Corrected/472.html.corrected.txt
# Corrected/473.html.corrected.txt
# Corrected/477.html.corrected.txt
# Corrected/478.html.corrected.txt
# Corrected/480.html.corrected.txt
# Corrected/485.html.corrected.txt
# Corrected/486.html.corrected.txt
# Corrected/488.html.corrected.txt
# Corrected/49.html.corrected.txt
# Corrected/492.html.corrected.txt
# Corrected/493.html.corrected.txt
# Corrected/495.html.corrected.txt
# Corrected/50.html.corrected.txt
# Corrected/500.html.corrected.txt
# Corrected/501.html.corrected.txt
# Corrected/503.html.corrected.txt
# Corrected/509.html.corrected.txt
# Corrected/510.html.corrected.txt
# Corrected/511.html.corrected.txt
# Corrected/513.html.corrected.txt
# Corrected/522.html.corrected.txt
# Corrected/524.html.corrected.txt
# Corrected/54.html.corrected.txt
# Corrected/58.html.corrected.txt
# Corrected/60.html.corrected.txt
# Corrected/66.html.corrected.txt
# Corrected/67.html.corrected.txt
# Corrected/68.html.corrected.txt
# Corrected/69.html.corrected.txt
# Corrected/75.html.corrected.txt
# Corrected/76.html.corrected.txt
# Corrected/77.html.corrected.txt
# Corrected/78.html.corrected.txt
# Corrected/79.html.corrected.txt
# Corrected/83.html.corrected.txt
# Corrected/85.html.corrected.txt
# Corrected/86.html.corrected.txt
# Corrected/88.html.corrected.txt
# Corrected/9.html.corrected.txt
# Corrected/90.html.corrected.txt
# Corrected/94.html.corrected.txt
# Corrected/95.html.corrected.txt
# Corrected/97.html.corrected.txt
# Corrected/98.html.corrected.txt
# Corrected/99.html.corrected.txt
# Corrected/R1.html.corrected.txt
# Corrected/R10.html.corrected.txt
# Corrected/R100.html.corrected.txt
# Corrected/R1000.html.corrected.txt
# Corrected/R101.html.corrected.txt
# Corrected/R102.html.corrected.txt
# Corrected/R103.html.corrected.txt
# Corrected/R104.html.corrected.txt
# Corrected/R105.html.corrected.txt
# Corrected/R106.html.corrected.txt
# Corrected/R107.html.corrected.txt
# Corrected/R108.html.corrected.txt
# Corrected/R109.html.corrected.txt
# Corrected/R11.html.corrected.txt
# Corrected/R110.html.corrected.txt
# Corrected/R111.html.corrected.txt
# Corrected/R112.html.corrected.txt
# Corrected/R113.html.corrected.txt
# Corrected/R114.html.corrected.txt
# Corrected/R115.html.corrected.txt
# Corrected/R116.html.corrected.txt
# Corrected/R117.html.corrected.txt
# Corrected/R118.html.corrected.txt
# Corrected/R119.html.corrected.txt
# Corrected/R12.html.corrected.txt
# Corrected/R120.html.corrected.txt
# Corrected/R121.html.corrected.txt
# Corrected/R122.html.corrected.txt
# Corrected/R123.html.corrected.txt
# Corrected/R124.html.corrected.txt
# Corrected/R125.html.corrected.txt
# Corrected/R126.html.corrected.txt
# Corrected/R127.html.corrected.txt
# Corrected/R128.html.corrected.txt
# Corrected/R129.html.corrected.txt
# Corrected/R13.html.corrected.txt
# Corrected/R130.html.corrected.txt
# Corrected/R131.html.corrected.txt
# Corrected/R132.html.corrected.txt
# Corrected/R133.html.corrected.txt
# Corrected/R134.html.corrected.txt
# Corrected/R135.html.corrected.txt
# Corrected/R136.html.corrected.txt
# Corrected/R137.html.corrected.txt
# Corrected/R138.html.corrected.txt
# Corrected/R139.html.corrected.txt
# Corrected/R14.html.corrected.txt
# Corrected/R140.html.corrected.txt
# Corrected/R141.html.corrected.txt
# Corrected/R142.html.corrected.txt
# Corrected/R143.html.corrected.txt
# Corrected/R144.html.corrected.txt
# Corrected/R145.html.corrected.txt
# Corrected/R146.html.corrected.txt
# Corrected/R147.html.corrected.txt
# Corrected/R148.html.corrected.txt
# Corrected/R149.html.corrected.txt
# Corrected/R15.html.corrected.txt
# Corrected/R150.html.corrected.txt
# Corrected/R151.html.corrected.txt
# Corrected/R152.html.corrected.txt
# Corrected/R153.html.corrected.txt
# Corrected/R154.html.corrected.txt
# Corrected/R155.html.corrected.txt
# Corrected/R156.html.corrected.txt
# Corrected/R157.html.corrected.txt
# Corrected/R158.html.corrected.txt
# Corrected/R159.html.corrected.txt
# Corrected/R16.html.corrected.txt
# Corrected/R160.html.corrected.txt
# Corrected/R161.html.corrected.txt
# Corrected/R162.html.corrected.txt
# Corrected/R163.html.corrected.txt
# Corrected/R164.html.corrected.txt
# Corrected/R165.html.corrected.txt
# Corrected/R166.html.corrected.txt
# Corrected/R167.html.corrected.txt
# Corrected/R168.html.corrected.txt
# Corrected/R169.html.corrected.txt
# Corrected/R17.html.corrected.txt
# Corrected/R170.html.corrected.txt
# Corrected/R171.html.corrected.txt
# Corrected/R172.html.corrected.txt
# Corrected/R173.html.corrected.txt
# Corrected/R174.html.corrected.txt
# Corrected/R175.html.corrected.txt
# Corrected/R176.html.corrected.txt
# Corrected/R177.html.corrected.txt
# Corrected/R178.html.corrected.txt
# Corrected/R179.html.corrected.txt
# Corrected/R18.html.corrected.txt
# Corrected/R180.html.corrected.txt
# Corrected/R181.html.corrected.txt
# Corrected/R182.html.corrected.txt
# Corrected/R183.html.corrected.txt
# Corrected/R184.html.corrected.txt
# Corrected/R185.html.corrected.txt
# Corrected/R186.html.corrected.txt
# Corrected/R187.html.corrected.txt
# Corrected/R188.html.corrected.txt
# Corrected/R189.html.corrected.txt
# Corrected/R19.html.corrected.txt
# Corrected/R190.html.corrected.txt
# Corrected/R191.html.corrected.txt
# Corrected/R192.html.corrected.txt
# Corrected/R193.html.corrected.txt
# Corrected/R194.html.corrected.txt
# Corrected/R195.html.corrected.txt
# Corrected/R196.html.corrected.txt
# Corrected/R197.html.corrected.txt
# Corrected/R198.html.corrected.txt
# Corrected/R199.html.corrected.txt
# Corrected/R2.html.corrected.txt
# Corrected/R20.html.corrected.txt
# Corrected/R200.html.corrected.txt
# Corrected/R201.html.corrected.txt
# Corrected/R202.html.corrected.txt
# Corrected/R203.html.corrected.txt
# Corrected/R204.html.corrected.txt
# Corrected/R205.html.corrected.txt
# Corrected/R206.html.corrected.txt
# Corrected/R207.html.corrected.txt
# Corrected/R208.html.corrected.txt
# Corrected/R209.html.corrected.txt
# Corrected/R21.html.corrected.txt
# Corrected/R210.html.corrected.txt
# Corrected/R211.html.corrected.txt
# Corrected/R212.html.corrected.txt
# Corrected/R213.html.corrected.txt
# Corrected/R214.html.corrected.txt
# Corrected/R215.html.corrected.txt
# Corrected/R216.html.corrected.txt
# Corrected/R217.html.corrected.txt
# Corrected/R218.html.corrected.txt
# Corrected/R219.html.corrected.txt
# Corrected/R22.html.corrected.txt
# Corrected/R220.html.corrected.txt
# Corrected/R221.html.corrected.txt
# Corrected/R222.html.corrected.txt
# Corrected/R223.html.corrected.txt
# Corrected/R224.html.corrected.txt
# Corrected/R225.html.corrected.txt
# Corrected/R226.html.corrected.txt
# Corrected/R227.html.corrected.txt
# Corrected/R228.html.corrected.txt
# Corrected/R229.html.corrected.txt
# Corrected/R23.html.corrected.txt
# Corrected/R230.html.corrected.txt
# Corrected/R231.html.corrected.txt
# Corrected/R232.html.corrected.txt
# Corrected/R233.html.corrected.txt
# Corrected/R234.html.corrected.txt
# Corrected/R235.html.corrected.txt
# Corrected/R236.html.corrected.txt
# Corrected/R237.html.corrected.txt
# Corrected/R238.html.corrected.txt
# Corrected/R239.html.corrected.txt
# Corrected/R24.html.corrected.txt
# Corrected/R240.html.corrected.txt
# Corrected/R241.html.corrected.txt
# Corrected/R242.html.corrected.txt
# Corrected/R243.html.corrected.txt
# Corrected/R244.html.corrected.txt
# Corrected/R245.html.corrected.txt
# Corrected/R246.html.corrected.txt
# Corrected/R247.html.corrected.txt
# Corrected/R248.html.corrected.txt
# Corrected/R249.html.corrected.txt
# Corrected/R25.html.corrected.txt
# Corrected/R250.html.corrected.txt
# Corrected/R251.html.corrected.txt
# Corrected/R252.html.corrected.txt
# Corrected/R253.html.corrected.txt
# Corrected/R254.html.corrected.txt
# Corrected/R255.html.corrected.txt
# Corrected/R256.html.corrected.txt
# Corrected/R257.html.corrected.txt
# Corrected/R258.html.corrected.txt
# Corrected/R259.html.corrected.txt
# Corrected/R26.html.corrected.txt
# Corrected/R260.html.corrected.txt
# Corrected/R261.html.corrected.txt
# Corrected/R262.html.corrected.txt
# Corrected/R263.html.corrected.txt
# Corrected/R264.html.corrected.txt
# Corrected/R265.html.corrected.txt
# Corrected/R266.html.corrected.txt
# Corrected/R267.html.corrected.txt
# Corrected/R268.html.corrected.txt
# Corrected/R269.html.corrected.txt
# Corrected/R27.html.corrected.txt
# Corrected/R270.html.corrected.txt
# Corrected/R271.html.corrected.txt
# Corrected/R272.html.corrected.txt
# Corrected/R273.html.corrected.txt
# Corrected/R274.html.corrected.txt
# Corrected/R275.html.corrected.txt
# Corrected/R276.html.corrected.txt
# Corrected/R277.html.corrected.txt
# Corrected/R278.html.corrected.txt
# Corrected/R279.html.corrected.txt
# Corrected/R28.html.corrected.txt
# Corrected/R280.html.corrected.txt
# Corrected/R281.html.corrected.txt
# Corrected/R282.html.corrected.txt
# Corrected/R283.html.corrected.txt
# Corrected/R284.html.corrected.txt
# Corrected/R285.html.corrected.txt
# Corrected/R286.html.corrected.txt
# Corrected/R287.html.corrected.txt
# Corrected/R288.html.corrected.txt
# Corrected/R289.html.corrected.txt
# Corrected/R29.html.corrected.txt
# Corrected/R290.html.corrected.txt
# Corrected/R291.html.corrected.txt
# Corrected/R292.html.corrected.txt
# Corrected/R293.html.corrected.txt
# Corrected/R294.html.corrected.txt
# Corrected/R295.html.corrected.txt
# Corrected/R296.html.corrected.txt
# Corrected/R297.html.corrected.txt
# Corrected/R298.html.corrected.txt
# Corrected/R299.html.corrected.txt
# Corrected/R3.html.corrected.txt
# Corrected/R30.html.corrected.txt
# Corrected/R300.html.corrected.txt
# Corrected/R301.html.corrected.txt
# Corrected/R302.html.corrected.txt
# Corrected/R303.html.corrected.txt
# Corrected/R304.html.corrected.txt
# Corrected/R305.html.corrected.txt
# Corrected/R306.html.corrected.txt
# Corrected/R307.html.corrected.txt
# Corrected/R308.html.corrected.txt
# Corrected/R309.html.corrected.txt
# Corrected/R31.html.corrected.txt
# Corrected/R310.html.corrected.txt
# Corrected/R311.html.corrected.txt
# Corrected/R312.html.corrected.txt
# Corrected/R313.html.corrected.txt
# Corrected/R314.html.corrected.txt
# Corrected/R315.html.corrected.txt
# Corrected/R316.html.corrected.txt
# Corrected/R317.html.corrected.txt
# Corrected/R318.html.corrected.txt
# Corrected/R319.html.corrected.txt
# Corrected/R32.html.corrected.txt
# Corrected/R320.html.corrected.txt
# Corrected/R321.html.corrected.txt
# Corrected/R322.html.corrected.txt
# Corrected/R323.html.corrected.txt
# Corrected/R324.html.corrected.txt
# Corrected/R325.html.corrected.txt
# Corrected/R326.html.corrected.txt
# Corrected/R327.html.corrected.txt
# Corrected/R328.html.corrected.txt
# Corrected/R329.html.corrected.txt
# Corrected/R33.html.corrected.txt
# Corrected/R330.html.corrected.txt
# Corrected/R331.html.corrected.txt
# Corrected/R332.html.corrected.txt
# Corrected/R333.html.corrected.txt
# Corrected/R334.html.corrected.txt
# Corrected/R335.html.corrected.txt
# Corrected/R336.html.corrected.txt
# Corrected/R337.html.corrected.txt
# Corrected/R338.html.corrected.txt
# Corrected/R339.html.corrected.txt
# Corrected/R34.html.corrected.txt
# Corrected/R340.html.corrected.txt
# Corrected/R341.html.corrected.txt
# Corrected/R342.html.corrected.txt
# Corrected/R343.html.corrected.txt
# Corrected/R344.html.corrected.txt
# Corrected/R345.html.corrected.txt
# Corrected/R346.html.corrected.txt
# Corrected/R347.html.corrected.txt
# Corrected/R348.html.corrected.txt
# Corrected/R349.html.corrected.txt
# Corrected/R35.html.corrected.txt
# Corrected/R350.html.corrected.txt
# Corrected/R351.html.corrected.txt
# Corrected/R352.html.corrected.txt
# Corrected/R353.html.corrected.txt
# Corrected/R354.html.corrected.txt
# Corrected/R355.html.corrected.txt
# Corrected/R356.html.corrected.txt
# Corrected/R357.html.corrected.txt
# Corrected/R358.html.corrected.txt
# Corrected/R359.html.corrected.txt
# Corrected/R36.html.corrected.txt
# Corrected/R360.html.corrected.txt
# Corrected/R361.html.corrected.txt
# Corrected/R362.html.corrected.txt
# Corrected/R363.html.corrected.txt
# Corrected/R364.html.corrected.txt
# Corrected/R365.html.corrected.txt
# Corrected/R366.html.corrected.txt
# Corrected/R367.html.corrected.txt
# Corrected/R368.html.corrected.txt
# Corrected/R369.html.corrected.txt
# Corrected/R37.html.corrected.txt
# Corrected/R370.html.corrected.txt
# Corrected/R371.html.corrected.txt
# Corrected/R372.html.corrected.txt
# Corrected/R373.html.corrected.txt
# Corrected/R374.html.corrected.txt
# Corrected/R375.html.corrected.txt
# Corrected/R376.html.corrected.txt
# Corrected/R377.html.corrected.txt
# Corrected/R378.html.corrected.txt
# Corrected/R379.html.corrected.txt
# Corrected/R38.html.corrected.txt
# Corrected/R380.html.corrected.txt
# Corrected/R381.html.corrected.txt
# Corrected/R382.html.corrected.txt
# Corrected/R383.html.corrected.txt
# Corrected/R384.html.corrected.txt
# Corrected/R385.html.corrected.txt
# Corrected/R386.html.corrected.txt
# Corrected/R387.html.corrected.txt
# Corrected/R388.html.corrected.txt
# Corrected/R389.html.corrected.txt
# Corrected/R39.html.corrected.txt
# Corrected/R390.html.corrected.txt
# Corrected/R391.html.corrected.txt
# Corrected/R392.html.corrected.txt
# Corrected/R393.html.corrected.txt
# Corrected/R394.html.corrected.txt
# Corrected/R395.html.corrected.txt
# Corrected/R396.html.corrected.txt
# Corrected/R397.html.corrected.txt
# Corrected/R398.html.corrected.txt
# Corrected/R399.html.corrected.txt
# Corrected/R4.html.corrected.txt
# Corrected/R40.html.corrected.txt
# Corrected/R400.html.corrected.txt
# Corrected/R401.html.corrected.txt
# Corrected/R402.html.corrected.txt
# Corrected/R403.html.corrected.txt
# Corrected/R404.html.corrected.txt
# Corrected/R405.html.corrected.txt
# Corrected/R406.html.corrected.txt
# Corrected/R407.html.corrected.txt
# Corrected/R408.html.corrected.txt
# Corrected/R409.html.corrected.txt
# Corrected/R41.html.corrected.txt
# Corrected/R410.html.corrected.txt
# Corrected/R411.html.corrected.txt
# Corrected/R412.html.corrected.txt
# Corrected/R413.html.corrected.txt
# Corrected/R414.html.corrected.txt
# Corrected/R415.html.corrected.txt
# Corrected/R416.html.corrected.txt
# Corrected/R417.html.corrected.txt
# Corrected/R418.html.corrected.txt
# Corrected/R419.html.corrected.txt
# Corrected/R42.html.corrected.txt
# Corrected/R420.html.corrected.txt
# Corrected/R421.html.corrected.txt
# Corrected/R422.html.corrected.txt
# Corrected/R423.html.corrected.txt
# Corrected/R424.html.corrected.txt
# Corrected/R425.html.corrected.txt
# Corrected/R426.html.corrected.txt
# Corrected/R427.html.corrected.txt
# Corrected/R428.html.corrected.txt
# Corrected/R429.html.corrected.txt
# Corrected/R43.html.corrected.txt
# Corrected/R430.html.corrected.txt
# Corrected/R431.html.corrected.txt
# Corrected/R432.html.corrected.txt
# Corrected/R433.html.corrected.txt
# Corrected/R434.html.corrected.txt
# Corrected/R435.html.corrected.txt
# Corrected/R436.html.corrected.txt
# Corrected/R437.html.corrected.txt
# Corrected/R438.html.corrected.txt
# Corrected/R439.html.corrected.txt
# Corrected/R44.html.corrected.txt
# Corrected/R440.html.corrected.txt
# Corrected/R441.html.corrected.txt
# Corrected/R442.html.corrected.txt
# Corrected/R443.html.corrected.txt
# Corrected/R444.html.corrected.txt
# Corrected/R445.html.corrected.txt
# Corrected/R446.html.corrected.txt
# Corrected/R447.html.corrected.txt
# Corrected/R448.html.corrected.txt
# Corrected/R449.html.corrected.txt
# Corrected/R45.html.corrected.txt
# Corrected/R450.html.corrected.txt
# Corrected/R451.html.corrected.txt
# Corrected/R452.html.corrected.txt
# Corrected/R453.html.corrected.txt
# Corrected/R454.html.corrected.txt
# Corrected/R455.html.corrected.txt
# Corrected/R456.html.corrected.txt
# Corrected/R457.html.corrected.txt
# Corrected/R458.html.corrected.txt
# Corrected/R459.html.corrected.txt
# Corrected/R46.html.corrected.txt
# Corrected/R460.html.corrected.txt
# Corrected/R461.html.corrected.txt
# Corrected/R462.html.corrected.txt
# Corrected/R463.html.corrected.txt
# Corrected/R464.html.corrected.txt
# Corrected/R465.html.corrected.txt
# Corrected/R466.html.corrected.txt
# Corrected/R467.html.corrected.txt
# Corrected/R468.html.corrected.txt
# Corrected/R469.html.corrected.txt
# Corrected/R47.html.corrected.txt
# Corrected/R470.html.corrected.txt
# Corrected/R471.html.corrected.txt
# Corrected/R473.html.corrected.txt
# Corrected/R474.html.corrected.txt
# Corrected/R475.html.corrected.txt
# Corrected/R476.html.corrected.txt
# Corrected/R477.html.corrected.txt
# Corrected/R478.html.corrected.txt
# Corrected/R479.html.corrected.txt
# Corrected/R48.html.corrected.txt
# Corrected/R480.html.corrected.txt
# Corrected/R481.html.corrected.txt
# Corrected/R482.html.corrected.txt
# Corrected/R483.html.corrected.txt
# Corrected/R484.html.corrected.txt
# Corrected/R485.html.corrected.txt
# Corrected/R486.html.corrected.txt
# Corrected/R487.html.corrected.txt
# Corrected/R488.html.corrected.txt
# Corrected/R489.html.corrected.txt
# Corrected/R49.html.corrected.txt
# Corrected/R490.html.corrected.txt
# Corrected/R491.html.corrected.txt
# Corrected/R492.html.corrected.txt
# Corrected/R493.html.corrected.txt
# Corrected/R494.html.corrected.txt
# Corrected/R495.html.corrected.txt
# Corrected/R496.html.corrected.txt
# Corrected/R497.html.corrected.txt
# Corrected/R498.html.corrected.txt
# Corrected/R499.html.corrected.txt
# Corrected/R5.html.corrected.txt
# Corrected/R50.html.corrected.txt
# Corrected/R500.html.corrected.txt
# Corrected/R501.html.corrected.txt
# Corrected/R502.html.corrected.txt
# Corrected/R503.html.corrected.txt
# Corrected/R504.html.corrected.txt
# Corrected/R505.html.corrected.txt
# Corrected/R506.html.corrected.txt
# Corrected/R507.html.corrected.txt
# Corrected/R508.html.corrected.txt
# Corrected/R509.html.corrected.txt
# Corrected/R51.html.corrected.txt
# Corrected/R510.html.corrected.txt
# Corrected/R511.html.corrected.txt
# Corrected/R512.html.corrected.txt
# Corrected/R513.html.corrected.txt
# Corrected/R514.html.corrected.txt
# Corrected/R515.html.corrected.txt
# Corrected/R516.html.corrected.txt
# Corrected/R517.html.corrected.txt
# Corrected/R518.html.corrected.txt
# Corrected/R519.html.corrected.txt
# Corrected/R52.html.corrected.txt
# Corrected/R520.html.corrected.txt
# Corrected/R521.html.corrected.txt
# Corrected/R522.html.corrected.txt
# Corrected/R523.html.corrected.txt
# Corrected/R524.html.corrected.txt
# Corrected/R525.html.corrected.txt
# Corrected/R526.html.corrected.txt
# Corrected/R527.html.corrected.txt
# Corrected/R528.html.corrected.txt
# Corrected/R529.html.corrected.txt
# Corrected/R53.html.corrected.txt
# Corrected/R530.html.corrected.txt
# Corrected/R531.html.corrected.txt
# Corrected/R532.html.corrected.txt
# Corrected/R533.html.corrected.txt
# Corrected/R534.html.corrected.txt
# Corrected/R535.html.corrected.txt
# Corrected/R536.html.corrected.txt
# Corrected/R537.html.corrected.txt
# Corrected/R538.html.corrected.txt
# Corrected/R539.html.corrected.txt
# Corrected/R54.html.corrected.txt
# Corrected/R540.html.corrected.txt
# Corrected/R541.html.corrected.txt
# Corrected/R542.html.corrected.txt
# Corrected/R543.html.corrected.txt
# Corrected/R544.html.corrected.txt
# Corrected/R545.html.corrected.txt
# Corrected/R546.html.corrected.txt
# Corrected/R547.html.corrected.txt
# Corrected/R548.html.corrected.txt
# Corrected/R549.html.corrected.txt
# Corrected/R55.html.corrected.txt
# Corrected/R550.html.corrected.txt
# Corrected/R551.html.corrected.txt
# Corrected/R552.html.corrected.txt
# Corrected/R553.html.corrected.txt
# Corrected/R554.html.corrected.txt
# Corrected/R555.html.corrected.txt
# Corrected/R556.html.corrected.txt
# Corrected/R557.html.corrected.txt
# Corrected/R558.html.corrected.txt
# Corrected/R559.html.corrected.txt
# Corrected/R56.html.corrected.txt
# Corrected/R560.html.corrected.txt
# Corrected/R561.html.corrected.txt
# Corrected/R562.html.corrected.txt
# Corrected/R563.html.corrected.txt
# Corrected/R564.html.corrected.txt
# Corrected/R565.html.corrected.txt
# Corrected/R566.html.corrected.txt
# Corrected/R567.html.corrected.txt
# Corrected/R568.html.corrected.txt
# Corrected/R569.html.corrected.txt
# Corrected/R57.html.corrected.txt
# Corrected/R570.html.corrected.txt
# Corrected/R571.html.corrected.txt
# Corrected/R572.html.corrected.txt
# Corrected/R573.html.corrected.txt
# Corrected/R574.html.corrected.txt
# Corrected/R575.html.corrected.txt
# Corrected/R576.html.corrected.txt
# Corrected/R577.html.corrected.txt
# Corrected/R578.html.corrected.txt
# Corrected/R579.html.corrected.txt
# Corrected/R58.html.corrected.txt
# Corrected/R580.html.corrected.txt
# Corrected/R581.html.corrected.txt
# Corrected/R582.html.corrected.txt
# Corrected/R583.html.corrected.txt
# Corrected/R584.html.corrected.txt
# Corrected/R585.html.corrected.txt
# Corrected/R586.html.corrected.txt
# Corrected/R587.html.corrected.txt
# Corrected/R588.html.corrected.txt
# Corrected/R589.html.corrected.txt
# Corrected/R59.html.corrected.txt
# Corrected/R590.html.corrected.txt
# Corrected/R591.html.corrected.txt
# Corrected/R592.html.corrected.txt
# Corrected/R593.html.corrected.txt
# Corrected/R594.html.corrected.txt
# Corrected/R595.html.corrected.txt
# Corrected/R596.html.corrected.txt
# Corrected/R597.html.corrected.txt
# Corrected/R598.html.corrected.txt
# Corrected/R599.html.corrected.txt
# Corrected/R6.html.corrected.txt
# Corrected/R60.html.corrected.txt
# Corrected/R600.html.corrected.txt
# Corrected/R601.html.corrected.txt
# Corrected/R602.html.corrected.txt
# Corrected/R603.html.corrected.txt
# Corrected/R604.html.corrected.txt
# Corrected/R605.html.corrected.txt
# Corrected/R606.html.corrected.txt
# Corrected/R607.html.corrected.txt
# Corrected/R608.html.corrected.txt
# Corrected/R609.html.corrected.txt
# Corrected/R61.html.corrected.txt
# Corrected/R610.html.corrected.txt
# Corrected/R611.html.corrected.txt
# Corrected/R612.html.corrected.txt
# Corrected/R613.html.corrected.txt
# Corrected/R614.html.corrected.txt
# Corrected/R615.html.corrected.txt
# Corrected/R616.html.corrected.txt
# Corrected/R617.html.corrected.txt
# Corrected/R618.html.corrected.txt
# Corrected/R619.html.corrected.txt
# Corrected/R62.html.corrected.txt
# Corrected/R620.html.corrected.txt
# Corrected/R621.html.corrected.txt
# Corrected/R622.html.corrected.txt
# Corrected/R623.html.corrected.txt
# Corrected/R624.html.corrected.txt
# Corrected/R625.html.corrected.txt
# Corrected/R626.html.corrected.txt
# Corrected/R627.html.corrected.txt
# Corrected/R628.html.corrected.txt
# Corrected/R629.html.corrected.txt
# Corrected/R63.html.corrected.txt
# Corrected/R630.html.corrected.txt
# Corrected/R631.html.corrected.txt
# Corrected/R632.html.corrected.txt
# Corrected/R633.html.corrected.txt
# Corrected/R634.html.corrected.txt
# Corrected/R635.html.corrected.txt
# Corrected/R636.html.corrected.txt
# Corrected/R637.html.corrected.txt
# Corrected/R638.html.corrected.txt
# Corrected/R639.html.corrected.txt
# Corrected/R64.html.corrected.txt
# Corrected/R640.html.corrected.txt
# Corrected/R641.html.corrected.txt
# Corrected/R642.html.corrected.txt
# Corrected/R643.html.corrected.txt
# Corrected/R644.html.corrected.txt
# Corrected/R645.html.corrected.txt
# Corrected/R646.html.corrected.txt
# Corrected/R647.html.corrected.txt
# Corrected/R648.html.corrected.txt
# Corrected/R649.html.corrected.txt
# Corrected/R65.html.corrected.txt
# Corrected/R650.html.corrected.txt
# Corrected/R651.html.corrected.txt
# Corrected/R652.html.corrected.txt
# Corrected/R653.html.corrected.txt
# Corrected/R654.html.corrected.txt
# Corrected/R655.html.corrected.txt
# Corrected/R656.html.corrected.txt
# ...
#  50350K .......... .......... .......... .......... .......... 83% 3.34M 3s
#  50400K .......... .......... .......... .......... .......... 83% 8.21M 3s
#  50450K .......... .......... .......... .......... .......... 84% 5.42M 3s
#  50500K .......... .......... .......... .......... .......... 84% 10.4M 3s
#  50550K .......... .......... .......... .......... .......... 84% 7.20M 3s
# rm: cannot remove 'vips': No such file or directory
# rm: cannot remove 'vips': No such file or directory
# rm: cannot remove 'stripped': No such file or directory
# rm: cannot remove 'vips': No such file or directory
# rm: cannot remove 'stripped': No such file or directory
# rm: cannot remove 'vips': No such file or directory
# rm: cannot remove 'stripped': No such file or directory
# rm: cannot remove 'vips': No such file or directory
# rm: cannot remove 'stripped': No such file or directory
# rm: cannot remove 'vips': No such file or directory
# rm: cannot remove 'stripped': No such file or directory
# rm: cannot remove 'vips': No such file or directory
# rm: cannot remove 'stripped': No such file or directory
# rm: cannot remove 'vips': No such file or directory
# rm: cannot remove 'stripped': No such file or directory
# rm: cannot remove 'vips': No such file or directory
# rm: cannot remove 'stripped': No such file or directory
# rm: cannot remove 'vips': No such file or directory
# rm: cannot remove 'stripped': No such file or directory

# %% [markdown]
# After further investigation, there seem to be some inconsistencies regarding the encoding of the files(a few of them aren't UTF-8)  . We are going to solve that with a small bash snippet that converts the inconsistent files and remove the ones which are impossible to convert.

# %%
# %%bash
# cd ../data/external/
# # convert both txt and html files
# for f in $(find . -name "*.txt" -o -name "*.html"); do
#         encoding=$(file -i $f | cut -d"=" -f 2)  # get the mime encoding
#         if [ "$encoding" != "us-ascii" ] && [ "$encoding" != "utf-8" ]; then
#                 res=$(chardetect $f)  # try to detect it otherwise
#                 encoding=$(echo $res | cut -d" " -f 2)
#                 echo $res - CONVERTING TO UTF-8
#                 recode ${encoding}..utf-8 $f
#         fi
# done
#
# # remove the unsolvable ones
# cd dragnet
# rm HTML/{R121,T19,T2,T31}.html Corrected/{R121,T19,T2,T31}.html.corrected.txt
# cd ../cleaneval
# rm HTML/{114,276,305,376,767,331,619,716}.html Corrected/{114,276,305,376,767,331,619,716}.html.corrected.txt
# Out:
# ./cleaneval/Corrected/15.html.corrected.txt: Windows-1252 with confidence 0.7246884564300976 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/250.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/212.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/215.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/216.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/217.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/219.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/221.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/222.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/223.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/226.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/227.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/232.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/233.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/234.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/235.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/237.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/238.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/239.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/241.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/247.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/249.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/251.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/252.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/253.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/254.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/255.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/256.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/260.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/278.html.corrected.txt: no result - CONVERTING TO UTF-8
# ./cleaneval/Corrected/32.html.corrected.txt: no result - CONVERTING TO UTF-8
# ./cleaneval/Corrected/396.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/401.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/59.html.corrected.txt: ISO-8859-1 with confidence 0.7229027777777778 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/652.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/629.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/631.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/635.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/637.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/638.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/639.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/642.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/646.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/649.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/651.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/654.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/655.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/690.html.corrected.txt: no result - CONVERTING TO UTF-8
# ./cleaneval/Corrected/707.html.corrected.txt: no result - CONVERTING TO UTF-8
# ./cleaneval/Corrected/716.html.corrected.txt: CP949 with confidence 0.99 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/737.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/Corrected/749.html.corrected.txt: ISO-8859-1 with confidence 0.7290923444315064 - CONVERTING TO UTF-8
# ./cleaneval/HTML/445.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/1.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/105.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/108.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/110.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/114.html: Windows-1254 with confidence 0.4592231792203991 - CONVERTING TO UTF-8
# ./cleaneval/HTML/118.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/119.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/120.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/125.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/126.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/136.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/137.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/15.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/150.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/157.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/158.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/159.html: ascii with confidence 1.0 - CONVERTING TO UTF-8
# ./cleaneval/HTML/160.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/163.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/165.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/166.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/175.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/176.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/177.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/178.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/181.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/184.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/185.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/187.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/135.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/209.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/227.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/318.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/372.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/409.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/194.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/195.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/196.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/197.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/2.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/201.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/21.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/210.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/211.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/213.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/216.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/217.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/218.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/22.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/222.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/23.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/235.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/237.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/241.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/250.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/255.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/256.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/257.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/265.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/267.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/27.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/275.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/276.html: CP949 with confidence 0.99 - CONVERTING TO UTF-8
# ./cleaneval/HTML/277.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/28.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/284.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/285.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/287.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/288.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/289.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/292.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/296.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/298.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/299.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/300.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/301.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/305.html: CP949 with confidence 0.99 - CONVERTING TO UTF-8
# ./cleaneval/HTML/306.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/308.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/309.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/314.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/317.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/320.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/321.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/322.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/323.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/33.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/332.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/338.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/34.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/341.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/343.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/346.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/347.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/348.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/35.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/350.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/351.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/353.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/355.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/356.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/357.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/359.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/360.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/365.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/368.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/373.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/374.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/376.html: Windows-1254 with confidence 0.5552666957696839 - CONVERTING TO UTF-8
# ./cleaneval/HTML/38.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/383.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/388.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/39.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/393.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/395.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/396.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/399.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/4.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/401.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/404.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/405.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/41.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/429.html: SHIFT_JIS with confidence 0.99 - CONVERTING TO UTF-8
# ./cleaneval/HTML/430.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/436.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/438.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/439.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/441.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/442.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/443.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/448.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/450.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/453.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/455.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/458.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/46.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/464.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/465.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/466.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/467.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/470.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/471.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/477.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/479.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/48.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/480.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/482.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/487.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/492.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/493.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/498.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/500.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/502.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/503.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/505.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/506.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/510.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/561.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/563.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/564.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/565.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/566.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/569.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/571.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/573.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/575.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/577.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/58.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/582.html: Windows-1252 with confidence 0.7131148804934464 - CONVERTING TO UTF-8
# ./cleaneval/HTML/583.html: MacCyrillic with confidence 0.877679684070421 - CONVERTING TO UTF-8
# ./cleaneval/HTML/584.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/586.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/587.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/588.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/589.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/595.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/597.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/599.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/602.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/604.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/607.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/609.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/610.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/616.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/617.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/621.html: EUC-KR with confidence 0.875 - CONVERTING TO UTF-8
# ./cleaneval/HTML/623.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/626.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/629.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/638.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/639.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/646.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/649.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/652.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/654.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/655.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/661.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/665.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/667.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/669.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/677.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/679.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/683.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/686.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/690.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/693.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/695.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/70.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/700.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/704.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/709.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/710.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/711.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/714.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/715.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/716.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/717.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/726.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/727.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/730.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/731.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/733.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/736.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/738.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/739.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/742.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/746.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/748.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/75.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/752.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/754.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/755.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/757.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/758.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/759.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/76.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/760.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/762.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/763.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/764.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/767.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/771.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/772.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/782.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/783.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/790.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/793.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/794.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/8.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/574.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/592.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/611.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/631.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/651.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/691.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/747.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/765.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/83.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/93.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/94.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/95.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/96.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./cleaneval/HTML/97.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/102.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/103.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/106.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/108.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/109.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/116.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/117.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/119.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/128.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/134.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/14.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/141.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/142.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/143.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/145.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/151.html.corrected.txt: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/152.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/153.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/158.html.corrected.txt: UTF-16 with confidence 1.0 - CONVERTING TO UTF-8
# ./dragnet/Corrected/160.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/170.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/172.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/19.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/20.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/28.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/78.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/27.html.corrected.txt: UTF-16 with confidence 1.0 - CONVERTING TO UTF-8
# ./dragnet/Corrected/30.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/35.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/39.html.corrected.txt: UTF-16 with confidence 1.0 - CONVERTING TO UTF-8
# ./dragnet/Corrected/42.html.corrected.txt: UTF-16 with confidence 1.0 - CONVERTING TO UTF-8
# ./dragnet/Corrected/49.html.corrected.txt: UTF-16 with confidence 1.0 - CONVERTING TO UTF-8
# ./dragnet/Corrected/54.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/58.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/60.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/67.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/69.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/79.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/85.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/88.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/94.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/97.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/Corrected/99.html.corrected.txt: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/HTML/R121.html: Windows-1254 with confidence 0.5434633906826465 - CONVERTING TO UTF-8
# ./dragnet/HTML/R17.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/HTML/R736.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/HTML/R757.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/HTML/R826.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/HTML/R827.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/HTML/T156.html: windows-1251 with confidence 0.7538428528079772 - CONVERTING TO UTF-8
# ./dragnet/HTML/T19.html: Windows-1252 with confidence 0.73 - CONVERTING TO UTF-8
# ./dragnet/HTML/T2.html: Windows-1254 with confidence 0.5434729438118417 - CONVERTING TO UTF-8
# ./dragnet/HTML/T31.html: Windows-1254 with confidence 0.5239184224706976 - CONVERTING TO UTF-8
# ./dragnet/HTML/T97.html: ISO-8859-1 with confidence 0.73 - CONVERTING TO UTF-8
# recode: ./cleaneval/Corrected/716.html.corrected.txt failed: Invalid input in step `CP949..UTF-8'
# recode: ./cleaneval/HTML/114.html failed: Untranslatable input in step `CP1254..ISO-10646-UCS-2'
# recode: ./cleaneval/HTML/276.html failed: Invalid input in step `CP949..UTF-8'
# recode: ./cleaneval/HTML/305.html failed: Invalid input in step `CP949..UTF-8'
# recode: ./cleaneval/HTML/376.html failed: Untranslatable input in step `CP1254..ISO-10646-UCS-2'
# recode: ./cleaneval/HTML/767.html failed: Untranslatable input in step `CP1252..ISO-10646-UCS-2'
# recode: ./dragnet/HTML/R121.html failed: Untranslatable input in step `CP1254..ISO-10646-UCS-2'
# recode: ./dragnet/HTML/T19.html failed: Untranslatable input in step `CP1252..ISO-10646-UCS-2'
# recode: ./dragnet/HTML/T2.html failed: Untranslatable input in step `CP1254..ISO-10646-UCS-2'
# recode: ./dragnet/HTML/T31.html failed: Untranslatable input in step `CP1254..ISO-10646-UCS-2'

# %% [markdown]
# ## Converting to CSV
# Now that we have the html files, we can basically construct the csv, by setting the url column to be `file://filename.html` and the `html` column to the actual content of the file.

# %%
# %matplotlib inline

# standard library
import os
import re
from difflib import SequenceMatcher

# lxml
from lxml import etree

# pandas
import pandas as pd
import dask.dataframe as dd

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# this styling is purely my preference
# less chartjunk
sns.set_context('notebook', font_scale=1.5, rc={'line.linewidth': 2.5})
sns.set(style='ticks', palette='Set2')

# %%
# get the html files 
html_files = [file for file in os.listdir("../data/external/dragnet/HTML") if file.endswith(".html")]
html_files[:5]  # inspect the first few
# Out:
# ['R256.html', 'R581.html', '100.html', '102.html', '103.html']

# %%
# build the dataframe 
ddf = dd.from_pandas(data=pd.DataFrame({'file': html_files}), chunksize=10)
ddf.head()
# Out:
#         file
# 0  R256.html
# 1  R581.html
# 2   100.html
# 3   102.html
# 4   103.html

# %%
def read_dir_file(file, directory):
    """Read a file from a given directory"""
    with open(os.path.join(directory, file)) as fin:
        return fin.read()  # return the entire content

# test
read_dir_file('9.html', directory='../data/external/dragnet/HTML')[:20]
# Out:
# '<!DOCTYPE html><html'

# %%
ddf['html'] = ddf['file'].apply(read_dir_file, meta=('html', str), directory='../data/external/dragnet/HTML')
ddf['url'] = 'file://' + ddf['file']  # convert it to the proper format
ddf.head()  # sanity-check
# Out:
#         file                                               html  \
# 0  R256.html  \n<!DOCTYPE html>\n<html class="site-creativit...
# 1  R581.html  <!DOCTYPE html>\n<html dir="ltr" lang="en-US">...
# 2   100.html  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
# 3   102.html  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...
# 4   103.html  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...
#
#                 url
# 0  file://R256.html
# 1  file://R581.html
# 2   file://100.html
# 3   file://102.html
# 4   file://103.html

# %% [markdown]
# The results look good! We should be ready to persist them in a file

# %%
# %%bash
# mkdir ../data/raw/dragnet  # make the folder if it doesn't exist
# mkdir ../data/raw/cleaneval

# %%
# define a reusable function
def convert_dragnet_dataset(directory, prefix=''):
    """Returns a csv dataset from a dragnet one(or cleaneval).
    The urls are encoded as file://{suffix}{filename}"""
    html_dir = os.path.join(directory, "HTML")
    html_files = [file for file in os.listdir(html_dir) if file.endswith(".html")]
    
    ddf = dd.from_pandas(data=pd.DataFrame({'file': html_files}), chunksize=10)
    ddf['html'] = ddf['file'].apply(read_dir_file, meta=('html', str), directory=html_dir)
    ddf['url'] = 'file://' + prefix + ddf['file']  # convert it to the proper format
    return ddf

dragnet_ddf = convert_dragnet_dataset('../data/external/dragnet/', 'dragnet-')
cleaneval_ddf = convert_dragnet_dataset('../data/external/cleaneval/', 'cleaneval-')

# %% [markdown]
# Voila! We now have the dataset in our own, single CSV format. We can move on to extracting the labels. But before, we will be doing the same with the **CleanEval** dataset.

# %% [markdown]
# Now that we have the CSVs we can begin the labeling.
# ## Labeling
# Both the dragnet and the cleaneval dataset present the gold standard data as txt files with blocks that make up the text corpora. From these blocks we can identify what html tags they correspond to by doing a reverse fuzzy matching on each tag's text content. We can also find in some of them the `!@#$%^&*()  COMMENTS` line which separates comment blocks from the main content, so we could potentially add 3 classes. To conclude the **dragnet** ones look like this:

# %% [markdown]
# ```
# 23 July 2012
# 8 great talks on war and peace
#
# James Stavridis speaks at TED Global 2012
#
# “Walls don’t work,” James Stavridis declared at TEDGlobal 2012. A highly accomplished Navy Admiral, Stavridis recalls 20th-century phenomena like trench warfare and the Berlin Wall. “Instead of building walls for security, we need to build bridges.”
#
# In his brass-tacks talk, Stavridis lays down a vision of “open-source security,” which he defines as “connecting the international, the inter-agency, the private/public, and lashing it together with strategic communication.” The basic point: that to combat 21st-century threats like cybercrime, terrorism, trafficking and piracy, the military cannot work alone. Stavridis invokes the example of Wikipedia to make his point.
#
# “Wikipedia is not created by 12 brilliant people locked in a room writing articles. Wikipedia every day is tens of thousands of people inputting information,” Stavridis says. “It’s the perfect image for the fundamental point that no one of us is as smart as all of us thinking together.”
#
# Stavridis’ thoughts on security are surprising. After the jump, listen to 8 other TEDTalks that challenge you to think of war, peace and military life in new ways.
#
# ```
#
# As we can seem, the blocks are separable by series of newlines. As for **cleaneval**, the gold standard is presented in this format:
#
# ```
#
# <h>                           Clinical Applications
#
#  <p>   The following applications are supported by the various divisions of
#     Information Technology @ Johns Hopkins.  Please note that access to
#      some of these applications is restricted to computers on the Johns
#               Hopkins network and are not accessible off site.
#
#   <h>                               Allscripts
# <p>   Allscripts is a medication management solution enabling physicians to
#    create electronic prescriptions.  The system provides physicians with
#    important information at the point of prescribing, including formulary
#        management, drug utilization reviews and other key indicators.
#    Allscripts provides an automated physician charge entry tool which is
#                used to capture charges at the point of care.
#
#  <h>                         Applicant Tracking System
# <p>   Tracks demographics and status of job applicants BDM Pharmacy  JHH The
#       RxTFC system support the  Inpatient and Outpatient Clinic areas
#      supported by the five JHH Pharmacy satellites. The Investigational
#    Drug Department uses the system to track certain studies. The software
#     manages 10,000 daily doses and billing between $100-200,000/day. The
#    Pharmacy staff of 180 has been trained in the application according to
#                                 usage needs.
# ```

# %% [markdown]
# Slightly harder to parse, but all blocks start with an html tag and end with a blank line, or another tag.
#
# For easier evaluation of both the strings we will be collapsing whitespaces and fuzzy matching doesn't really care. We'll also replace all tabs with spaces for convenience.

# %%
def collapse_whitespace(strarg, remove_nl=False):
    """Returns a cleaned-up version of the block text
    It collapses  whitespaces, removes tabs, and, if specified,
    only keeps the tag delimiters(like in cleaneval) as newlines."""
    strarg = re.sub(r'\t+', ' ', strarg)  # replace tabs with spaces
    if remove_nl:
        # remove newlines, used for cleaneval
        # they will be replaced by the remove tags
        strarg = re.sub(r'\n', ' ', strarg)  
    strarg = re.sub(r'<[a-zA-Z]+>', '\n', strarg)
    strarg = re.sub(r' +',  ' ', strarg)  # collapse whitespace
    return strarg

def get_blocks(strarg, cleaneval=False):
    """Gets the sanitized blocks to use for fuzzy matching
    First sanitizes the entire text, then splits it, trims excessive
    whitespace and removes any null ones."""
    sanitized_str = collapse_whitespace(strarg, remove_nl=cleaneval)  # sanitize the string
    blocks = sanitized_str.split('\n')  # split each block of text
    stripped_blocks = (block.strip() for block in blocks)  # trim leading amnd trailing whitespace
    return [block for block in stripped_blocks if block]  # filter out nempty blocks

# %%
cleaneval_str = """
<h>                           Clinical Applications

 <p>   The following applications are supported by the various divisions of
    Information Technology @ Johns Hopkins.  Please note that access to
     some of these applications is restricted to computers on the Johns
              Hopkins network and are not accessible off site.

  <h>                               Allscripts
<p>   Allscripts is a medication management solution enabling physicians to
   create electronic prescriptions.  The system provides physicians with
   important information at the point of prescribing, including formulary
       management, drug utilization reviews and other key indicators.
   Allscripts provides an automated physician charge entry tool which is
               used to capture charges at the point of care.
"""

collapse_whitespace(cleaneval_str, True)
# Out:
# ' \n Clinical Applications \n The following applications are supported by the various divisions of Information Technology @ Johns Hopkins. Please note that access to some of these applications is restricted to computers on the Johns Hopkins network and are not accessible off site. \n Allscripts \n Allscripts is a medication management solution enabling physicians to create electronic prescriptions. The system provides physicians with important information at the point of prescribing, including formulary management, drug utilization reviews and other key indicators. Allscripts provides an automated physician charge entry tool which is used to capture charges at the point of care. '

# %%
dragnet_str = """
23 July 2012
8 great talks on war and peace

James Stavridis speaks at TED Global 2012

“Walls don’t work,” James Stavridis declared at TEDGlobal 2012. A highly accomplished Navy Admiral, Stavridis recalls 20th-century phenomena like trench warfare and the Berlin Wall. “Instead of building walls for security, we need to build bridges.”
"""

collapse_whitespace(dragnet_str)
# Out:
# '\n23 July 2012\n8 great talks on war and peace\n\nJames Stavridis speaks at TED Global 2012\n\n“Walls don’t work,” James Stavridis declared at TEDGlobal 2012. A highly accomplished Navy Admiral, Stavridis recalls 20th-century phenomena like trench warfare and the Berlin Wall. “Instead of building walls for security, we need to build bridges.”\n'

# %%
get_blocks(cleaneval_str, cleaneval=True)
# Out:
# ['Clinical Applications',
#  'The following applications are supported by the various divisions of Information Technology @ Johns Hopkins. Please note that access to some of these applications is restricted to computers on the Johns Hopkins network and are not accessible off site.',
#  'Allscripts',
#  'Allscripts is a medication management solution enabling physicians to create electronic prescriptions. The system provides physicians with important information at the point of prescribing, including formulary management, drug utilization reviews and other key indicators. Allscripts provides an automated physician charge entry tool which is used to capture charges at the point of care.']

# %%
get_blocks(dragnet_str, cleaneval=False)
# Out:
# ['23 July 2012',
#  '8 great talks on war and peace',
#  'James Stavridis speaks at TED Global 2012',
#  '“Walls don’t work,” James Stavridis declared at TEDGlobal 2012. A highly accomplished Navy Admiral, Stavridis recalls 20th-century phenomena like trench warfare and the Berlin Wall. “Instead of building walls for security, we need to build bridges.”']

# %% [markdown]
# The code works well, now we have to apply it to all the html of all the pages, but first, we should associate with each one of them the blocks that need to be extracted. Afterwards we will need to extract all the tags in the typical `url, path` format and their containing text.

# %%
def get_blocks_for_file(filename, directory, cleaneval=False):
    """For the given filename(the html file), and the root directory of
    the dataset, return its list of blocks. Can specify wether the dataset is
    clean eval or not."""
    corrected_dir = os.path.join(directory, "Corrected")
    filename = filename + '.corrected.txt'
    with open(os.path.join(corrected_dir, filename)) as f:
        content = f.read()  # retrieve the content
        
    return get_blocks(content, cleaneval=cleaneval)  # sanitize and return

# test
get_blocks_for_file('1.html', '../data/external/cleaneval/', cleaneval=True)
# Out:
# ["If you feel it's time to start taking action and get your property sold FAST and for TOP DOLLAR; here's a good place to start.",
#  'Your Home Will Sell',
#  '* Fast',
#  'For Top Dollar',
#  '* With the Least Amount of Hassle You will get these results because of our:',
#  '1. Unique Team System',
#  '2. Innovative Consumer Programs',
#  '3. Leading Edge Technology',
#  '4. Specialized Knowledge',
#  "72% of homeowners are dissatisfied with their agent's performance",
#  'Why?',
#  'The Major Reason: Poor Communication',
#  "The ABC's of Real Estate Marketing (What Most Realtors Do)",
#  'Advertise themselves',
#  'Bang a sign into your lawn',
#  'Create an ad for the paper (and maybe run it)',
#  'Download your listing to the MLS',
#  'Encourage their office to show it',
#  'Figure they might try an open house',
#  'Get on their knees and pray it will sell',
#  "This is the way real estate has been practiced for the past 100 years, and it's still the way many agents operate today, but...",
#  '... these traditional methods have proven to be less and less effective.',
#  "That's why we use the latest technology and proven consumer innovations which go far beyond this antiquated ABC approach."]

# %% [markdown]
# Now that we have the function we should be able to apply it to the entire dataset

# %%
dragnet_ddf['blocks'] = dragnet_ddf['file'].apply(get_blocks_for_file, directory='../data/external/dragnet/', 
                                                  cleaneval=False, meta=('blocks', object))
dragnet_ddf['blocks'].head()
# Out:
# 0    [30 Designs to Inspire You Before Christmas, P...
# 1    [Backgrounds become foreground in election nig...
# 2    [July 24, 2012 12:11 AM, Latest Amelia Earhart...
# 3    [The Dangerous Hubris of the Startup World, by...
# 4    [Binomial coefficient trick, by John on July 2...
# Name: blocks, dtype: object

# %%
cleaneval_ddf['blocks'] = cleaneval_ddf['file'].apply(get_blocks_for_file, directory='../data/external/cleaneval/', 
                                                  cleaneval=True, meta=('blocks', object))
cleaneval_ddf['blocks'].head()
# Out:
# 0    [Watering Tricks by Lisa Erickson, Watering ca...
# 1    [If you feel it's time to start taking action ...
# 2    [Some VERY interesting information on 666, by ...
# 3    [Re: Mobile Multimedia Messaging Service, From...
# 4    ["Bugs" in the 24 March 1999 Version, From: er...
# Name: blocks, dtype: object

# %% [markdown]
# We can now try to extract the tags and their respective text content.

# %%
def extract_text_from_html(html):
    """Given some html, return the" dataframe of
    paths and text contents.
    """
    # we will transfor the str to bytes, otherwise, lxml complains 
    # for some edge casse when the encoding is specified in the document
    root = etree.HTML(html.encode('utf-8'))  # get the nodes
    paths, texts = zip(*((node.getroottree().getpath(node), 
                          '' if node.tag is etree.Comment or node.tag is etree.PI else ''.join(node.itertext())) 
                         for node in root.iter()))
    return pd.DataFrame(data={'path': paths, 'text': texts})

html = dragnet_ddf['html'].head()[0]
extract_text_from_html(html).iloc[100:105]
# Out:
#                                                   path  \
# 100  /html/body/div[2]/div/div[2]/div[2]/div[2]/div...
# 101  /html/body/div[2]/div/div[2]/div[2]/div[2]/div...
# 102    /html/body/div[2]/div/div[2]/div[2]/div[2]/p[1]
# 103   /html/body/div[2]/div/div[2]/div[2]/div[2]/h3[1]
# 104    /html/body/div[2]/div/div[2]/div[2]/div[2]/p[2]
#
#                                                   text
# 100                                     in Inspiration
# 101                                        Inspiration
# 102  The holiday season is fast approaching and aro...
# 103                                 Season’s Greetings
# 104

# %%
def extract_text_from_df(df):
    """Given a dataframe of htmls and urls, return
    a dataframe of nodes and their text content.
    """
    grouped = df.groupby(level=0)[['html', 'url']]  # group by unique default index
    
    # apply receives each group as a Series if we are applying to a series
    # or as a Datafram in this case(with a single row)
    result = grouped.apply(lambda x: extract_text_from_html(x['html'].iat[0]).assign(url=x['url'].iat[0]))
    return result.reset_index(drop=True)  # drop the multiindex

extract_text_from_df(dragnet_ddf.head(2)).head()
# Out:
#                  path                                               text  \
# 0               /html  \n\n\t\n\n\t30 Designs to Inspire You Before C...
# 1          /html/head  \n\t\n\n\t30 Designs to Inspire You Before Chr...
# 2  /html/head/meta[1]
# 3    /html/head/title  30 Designs to Inspire You Before Christmas |  ...
# 4  /html/head/link[1]
#
#                         url
# 0  file://dragnet-R256.html
# 1  file://dragnet-R256.html
# 2  file://dragnet-R256.html
# 3  file://dragnet-R256.html
# 4  file://dragnet-R256.html

# %%
def extract_text_from_ddf(ddf):
    """The same a s the df version, but works with
    dask dataframes instead."""
    # we basicaly abuse map_partition's ability to expand indexes for lack of a working
    # groupby(level) in dask
    return ddf.map_partitions(extract_text_from_df, meta={'path': str, 'text': str, 'url': str}).clear_divisions()

extract_text_from_ddf(dragnet_ddf).head()
# Out:
#                  path                                               text  \
# 0               /html  \n\n\t\n\n\t30 Designs to Inspire You Before C...
# 1          /html/head  \n\t\n\n\t30 Designs to Inspire You Before Chr...
# 2  /html/head/meta[1]
# 3    /html/head/title  30 Designs to Inspire You Before Christmas |  ...
# 4  /html/head/link[1]
#
#                         url
# 0  file://dragnet-R256.html
# 1  file://dragnet-R256.html
# 2  file://dragnet-R256.html
# 3  file://dragnet-R256.html
# 4  file://dragnet-R256.html

# %% [markdown]
# Now that we have the text content we can correlate it to the blocks associated with the each one of the urls.

# %%
def block_max_ratio(ser, reference):
    """Receives a text and a series indexed by url
    in which to check for it.It returns the maximum fuzzy
    match ratio"""
    blocks = reference[ser['url']]  # get the blocks
    ratios = (SequenceMatcher(None, ser['text'], block).ratio() for block in blocks)  # do fuzzy matching for all
    return max(ratios, default=0.)  # return the maximum

# test
block_max_ratio(pd.Series(['a', 'as da '], index=['url', 'text']), pd.Series([['asadssad', 'ad'], ['werew']], index=['a', 'b']))
# Out:
# 0.5714285714285714

# %%
def block_max_ratio(ser, reference=None):
    """Receives a text and a series indexed by url
    in which to check for it.It returns the maximum fuzzy
    match ratio"""
    blocks = ser['blocks'] # get the blocks
    ratios = (SequenceMatcher(None, ser['text'], block).ratio() for block in blocks)  # do fuzzy matching for all
    return max(ratios, default=0.)  # return the maximum


def convert_dataset(directory, prefix, cleaneval=False, block_thresh=0.9, label_name='content'):
    """Given a directory for a dragnet-style dataset, return
    the `url,html` and the label dataframe. Can specify the 
    fuzzy threshold for which to consider a text corresponding to the block
    and also wether the tdataset is or not CleanEval"""
    html_ddf = convert_dragnet_dataset(directory, prefix)  # get the htl content
    html_ddf['blocks'] = html_ddf['file'].apply(get_blocks_for_file, directory=directory, 
                                                cleaneval=cleaneval, meta=('blocks', object))
    text_tag_ddf = extract_text_from_ddf(html_ddf)
    text_tag_df = text_tag_ddf.compute()
    
    # persist it for the lookup speedup
    html_df = html_ddf.compute()

    # get the ratios
    ratios = text_tag_df.merge(html_df, on='url')[['text', 'blocks']] \
             .apply(block_max_ratio, axis=1)
    # assign the label to the tags that hae the grates matchin ration of over
    # value of the threshold
    text_tag_df[label_name + '_label'] = ratios >= block_thresh  
    
    # return the content and the labels
    return html_df[['url', 'html']], text_tag_df[['url', 'path', label_name + '_label']]

# %%
# convert the cleaneval dataset
cleaneval_df, cleaneval_label_df = convert_dataset('../data/external/cleaneval/', 'cleaneval-', cleaneval=True)

cleaneval_df.to_csv('../data/raw/cleaneval/raw.csv', index=False)
cleaneval_label_df.to_csv('../data/raw/cleaneval/labels.csv', index=False)

# %%
dragnet_df, dragnet_label_df = convert_dataset('../data/external/dragnet/', 'dragnet-', cleaneval=False)

dragnet_df.to_csv('../data/raw/dragnet/raw.csv', index=False)
dragnet_label_df.to_csv('../data/raw/dragnet/labels.csv', index=False)

# %% [markdown]
# ## Conclusion
# After all this ran, the results should be now toed in the specified locations. The big caveat with this approach is that it take an absurdl long time. **TODO** The implementation should somehow leverage dask's parallelized `apply`, as currently, it take 24h+ for the dragnet dataset.
