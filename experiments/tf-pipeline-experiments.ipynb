# %% [markdown]
# Trying out estimators with our custom input pipeline

# %%
# %matplotlib inline
# standard library
import itertools
import sys, os
import re
import glob

# pandas
import pandas as pd
import dask.dataframe as dd
import dask.array as da
import dask


# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# tesnsorflow
import tensorflow as tf


# local imports
sys.path.append(os.path.join(os.getcwd(), "../src"))

from tf_utils import make_csv_pipeline, make_csv_col_tensors

# this styling is purely my preference
# less chartjunk
sns.set_context('notebook', font_scale=1.5, rc={'line.linewidth': 2.5})
sns.set(style='ticks', palette='Set2')

# %%
# we'll initiate a simple pipeline that takes 2 csv files
df = pd.read_csv('../data/final/cleaneval/dom-full-00.csv', nrows=10)
feature_cols = list(filter(lambda x: x not in ['url', 'path', 'content_label'], df.columns))
label_cols = ['content_label']

feature_cols[:5]
# Out:
# ['depth', 'sibling_pos', 'no_classes', 'id_len', 'class_len']

# %%
def input_fn():
    feature_tens, label_tens, = make_csv_pipeline(csv_files=['../data/final/cleaneval/dom-full-00.csv', '../data/final/cleaneval/dom-full-00.csv'],
                                                  feature_cols=feature_cols, label_cols=label_cols, num_epochs=20, batch_size=1000)

    return {'x': feature_tens}, label_tens

def test_input_fn():
    feature_tens, label_tens, = make_csv_pipeline(csv_files=['../data/final/cleaneval/dom-full-00.csv', '../data/final/cleaneval/dom-full-00.csv'],
                                                  feature_cols=feature_cols, label_cols=label_cols, num_epochs=1, batch_size=1000, shuffle=False)

    return {'x': feature_tens}, label_tens

# %% [markdown]
# Now that we have the tensors we should be able to just return them from a function and pass them to an estimator. To start with, we'll pass them to a simple linear classifier.

# %%
tf_feat_cols = [
    tf.feature_column.numeric_column('x', shape=(len(feature_cols)))
]
estiamtor = tf.contrib.learn.DNNClassifier(feature_columns=tf_feat_cols, hidden_units=(1000, 500, 200))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpc55tgrni
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9819a16a58>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpc55tgrni'}

# %%
# %%time
# train it
estiamtor.fit(input_fn=input_fn)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:642: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpc55tgrni/model.ckpt.
# INFO:tensorflow:loss = 53.9072, step = 1
# INFO:tensorflow:global_step/sec: 0.238298
# INFO:tensorflow:loss = 5.5348, step = 101 (419.645 sec)
# INFO:tensorflow:Saving checkpoints for 144 into /tmp/tmpc55tgrni/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.238272
# INFO:tensorflow:loss = 1.91086, step = 201 (419.689 sec)
# INFO:tensorflow:Saving checkpoints for 287 into /tmp/tmpc55tgrni/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.238226
# INFO:tensorflow:loss = 0.733354, step = 301 (419.769 sec)
# INFO:tensorflow:Saving checkpoints for 364 into /tmp/tmpc55tgrni/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.13644.
# CPU times: user 1h 47min 20s, sys: 1min, total: 1h 48min 20s
# Wall time: 25min 37s
# DNNClassifier(params={'head': <tensorflow.contrib.learn.python.learn.estimators.head._BinaryLogisticHead object at 0x7f98062857f0>, 'hidden_units': (1000, 500, 200), 'feature_columns': (_NumericColumn(key='x', shape=(1572,), default_value=None, dtype=tf.float32, normalizer_fn=None),), 'optimizer': None, 'activation_fn': <function relu at 0x7f980537bd90>, 'dropout': None, 'gradient_clip_norm': None, 'embedding_lr_multipliers': None, 'input_layer_min_slice_size': None})

# %%
estiamtor.evaluate(input_fn=test_input_fn)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:642: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-10-27-18:38:56
# INFO:tensorflow:Restoring parameters from /tmp/tmpc55tgrni/model.ckpt-364
# INFO:tensorflow:Finished evaluation at 2017-10-27-18:40:55
# INFO:tensorflow:Saving dict for global step 364: accuracy = 0.844611, accuracy/baseline_label_mean = 0.143667, accuracy/threshold_0.500000_mean = 0.844611, auc = 0.544095, auc_precision_recall = 0.171649, global_step = 364, labels/actual_label_mean = 0.143667, labels/prediction_mean = 0.104894, loss = 1.18294, precision/positive_threshold_0.500000_mean = 0.242054, recall/positive_threshold_0.500000_mean = 0.0382831
# {'accuracy': 0.84461111,
#  'accuracy/baseline_label_mean': 0.14366667,
#  'accuracy/threshold_0.500000_mean': 0.84461111,
#  'auc': 0.54409468,
#  'auc_precision_recall': 0.17164919,
#  'global_step': 364,
#  'labels/actual_label_mean': 0.14366667,
#  'labels/prediction_mean': 0.10489396,
#  'loss': 1.1829363,
#  'precision/positive_threshold_0.500000_mean': 0.24205379,
#  'recall/positive_threshold_0.500000_mean': 0.038283061}

# %%
tf.verify_tensor_all_finite
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-9c13661454f7> in <module>()
# ----> 1 tf.version()
#
# AttributeError: module 'tensorflow' has no attribute 'version'

# %%
tens_dict = make_csv_col_tensors(csv_files=['../data/final/cleaneval/dom-full-00.csv', '../data/final/cleaneval/dom-full-00.csv'], 
                                 shuffle=True, num_epochs=None, csv_decoder_kwargs={'convert_ints': True})

# %%
depth_tens, sibling_pos = tens_dict['depth'], tens_dict['sibling_pos']
depth_pred = tf.greater(depth_tens, [6])
selected_items = tf.reshape(tf.where(depth_pred), [-1])

found = tf.gather(tf.reshape(tf.stack([depth_tens, sibling_pos]), [-1, 2]), selected_items)
found
# Out:
# <tf.Tensor 'Gather_11:0' shape=(?, 2) dtype=float32>

# %%
with tf.Session() as sess:
    # variables must be initialized otherwise it fails 
    sess.run(tf.local_variables_initializer())
    sess.run(tf.global_variables_initializer())
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)

    # test the output
    for _ in range(40):
        print(sess.run([depth_tens, found]))
        print("\n=======") 

    # finish
    coord.request_stop()
    coord.join(threads)
# Out:
# [3.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [5.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [4.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [5.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [5.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [6.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [6.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [4.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [5.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [10.0, array([[ 10.,   0.]], dtype=float32)]
#
# =======
# [10.0, array([[ 10.,   7.]], dtype=float32)]
#
# =======
# [10.0, array([[ 10.,  11.]], dtype=float32)]
#
# =======
# [10.0, array([[ 10.,  24.]], dtype=float32)]
#
# =======
# [10.0, array([[ 10.,  36.]], dtype=float32)]
#
# =======
# [10.0, array([[ 10.,  54.]], dtype=float32)]
#
# =======
# [13.0, array([[ 13.,   1.]], dtype=float32)]
#
# =======
# [12.0, array([[ 12.,  30.]], dtype=float32)]
#
# =======
# [7.0, array([[ 7.,  0.]], dtype=float32)]
#
# =======
# [5.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [6.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [4.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [10.0, array([[ 10.,   0.]], dtype=float32)]
#
# =======
# [11.0, array([[ 11.,  19.]], dtype=float32)]
#
# =======
# [12.0, array([[ 12.,   7.]], dtype=float32)]
#
# =======
# [5.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [4.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [10.0, array([[ 10.,   0.]], dtype=float32)]
#
# =======
# [17.0, array([[ 17.,   0.]], dtype=float32)]
#
# =======
# [13.0, array([[ 13.,  53.]], dtype=float32)]
#
# =======
# [14.0, array([[ 14.,   5.]], dtype=float32)]
#
# =======
# [15.0, array([[ 15.,   0.]], dtype=float32)]
#
# =======
# [4.0, array([], shape=(0, 2), dtype=float32)]
#
# =======
# [7.0, array([[ 7.,  0.]], dtype=float32)]
#
# =======
# [7.0, array([[ 7.,  1.]], dtype=float32)]
#
# =======
# [17.0, array([[ 17.,   1.]], dtype=float32)]
#
# =======
# [16.0, array([[ 16.,  14.]], dtype=float32)]
#
# =======
# [16.0, array([[ 16.,  22.]], dtype=float32)]
#
# =======
# [12.0, array([[ 12.,   0.]], dtype=float32)]
#
# =======
# [14.0, array([[ 14.,   1.]], dtype=float32)]
#
# =======
# [14.0, array([[ 14.,   0.]], dtype=float32)]
#
# =======

# %%
tf.stack([depth_tens, sibling_pos])
# Out:
# <tf.Tensor 'stack_1:0' shape=(2,) dtype=float32>

# %%
# %pdb on
feature_tens, label_tens, = make_csv_pipeline(csv_pattern='../data/final/cleaneval/dom-full-0*.csv',
                                              feature_cols=feature_cols, label_cols=label_cols, num_epochs=20, batch_size=100, in_memory=True)
# Out:
# Automatic pdb calling has been turned ON
# WARNING:tensorflow:enqueue_data was called with num_epochs and num_threads > 1. num_epochs is applied per thread, so this will produce more epochs than you probably intend. If you want to limit epochs, use one thread.
# WARNING:tensorflow:enqueue_data was called with shuffle=True, num_threads > 1, and num_epochs. This will create multiple threads, all reading the array/dataframe in order adding to the same shuffling queue; the results will likely not be sufficiently shuffled.

# %%
tens_dict = make_csv_col_tensors(csv_files=['../data/final/cleaneval/dom-full-00.csv', '../data/final/cleaneval/dom-full-00.csv'],
                                              shuffle=False, num_epochs=1, csv_decoder_kwargs={'convert_ints': True})

# %%
tens_dict
# Out:
# {'depth': <tf.Tensor 'DecodeCSV:0' shape=() dtype=float32>,
#  'sibling_pos': <tf.Tensor 'DecodeCSV:1' shape=() dtype=float32>,
#  'no_classes': <tf.Tensor 'DecodeCSV:2' shape=() dtype=float32>,
#  'id_len': <tf.Tensor 'DecodeCSV:3' shape=() dtype=float32>,
#  'class_len': <tf.Tensor 'DecodeCSV:4' shape=() dtype=float32>,
#  'no_children': <tf.Tensor 'DecodeCSV:5' shape=() dtype=float32>,
#  'text_len': <tf.Tensor 'DecodeCSV:6' shape=() dtype=float32>,
#  'descendant1_no_nodes': <tf.Tensor 'DecodeCSV:7' shape=() dtype=float32>,
#  'descendant1_no_children_avg': <tf.Tensor 'DecodeCSV:8' shape=() dtype=float32>,
#  'descendant1_id_len_avg': <tf.Tensor 'DecodeCSV:9' shape=() dtype=float32>,
#  'descendant1_no_classes_avg': <tf.Tensor 'DecodeCSV:10' shape=() dtype=float32>,
#  'descendant1_class_len_avg': <tf.Tensor 'DecodeCSV:11' shape=() dtype=float32>,
#  'descendant1_text_len_avg': <tf.Tensor 'DecodeCSV:12' shape=() dtype=float32>,
#  'descendant2_no_nodes': <tf.Tensor 'DecodeCSV:13' shape=() dtype=float32>,
#  'descendant2_no_children_avg': <tf.Tensor 'DecodeCSV:14' shape=() dtype=float32>,
#  'descendant2_id_len_avg': <tf.Tensor 'DecodeCSV:15' shape=() dtype=float32>,
#  'descendant2_no_classes_avg': <tf.Tensor 'DecodeCSV:16' shape=() dtype=float32>,
#  'descendant2_class_len_avg': <tf.Tensor 'DecodeCSV:17' shape=() dtype=float32>,
#  'descendant2_text_len_avg': <tf.Tensor 'DecodeCSV:18' shape=() dtype=float32>,
#  'descendant3_no_nodes': <tf.Tensor 'DecodeCSV:19' shape=() dtype=float32>,
#  'descendant3_no_children_avg': <tf.Tensor 'DecodeCSV:20' shape=() dtype=float32>,
#  'descendant3_id_len_avg': <tf.Tensor 'DecodeCSV:21' shape=() dtype=float32>,
#  'descendant3_no_classes_avg': <tf.Tensor 'DecodeCSV:22' shape=() dtype=float32>,
#  'descendant3_class_len_avg': <tf.Tensor 'DecodeCSV:23' shape=() dtype=float32>,
#  'descendant3_text_len_avg': <tf.Tensor 'DecodeCSV:24' shape=() dtype=float32>,
#  'descendant4_no_nodes': <tf.Tensor 'DecodeCSV:25' shape=() dtype=float32>,
#  'descendant4_no_children_avg': <tf.Tensor 'DecodeCSV:26' shape=() dtype=float32>,
#  'descendant4_id_len_avg': <tf.Tensor 'DecodeCSV:27' shape=() dtype=float32>,
#  'descendant4_no_classes_avg': <tf.Tensor 'DecodeCSV:28' shape=() dtype=float32>,
#  'descendant4_class_len_avg': <tf.Tensor 'DecodeCSV:29' shape=() dtype=float32>,
#  'descendant4_text_len_avg': <tf.Tensor 'DecodeCSV:30' shape=() dtype=float32>,
#  'descendant5_no_nodes': <tf.Tensor 'DecodeCSV:31' shape=() dtype=float32>,
#  'descendant5_no_children_avg': <tf.Tensor 'DecodeCSV:32' shape=() dtype=float32>,
#  'descendant5_id_len_avg': <tf.Tensor 'DecodeCSV:33' shape=() dtype=float32>,
#  'descendant5_no_classes_avg': <tf.Tensor 'DecodeCSV:34' shape=() dtype=float32>,
#  'descendant5_class_len_avg': <tf.Tensor 'DecodeCSV:35' shape=() dtype=float32>,
#  'descendant5_text_len_avg': <tf.Tensor 'DecodeCSV:36' shape=() dtype=float32>,
#  'ancestor1_depth': <tf.Tensor 'DecodeCSV:37' shape=() dtype=float32>,
#  'ancestor1_sibling_pos': <tf.Tensor 'DecodeCSV:38' shape=() dtype=float32>,
#  'ancestor1_no_classes': <tf.Tensor 'DecodeCSV:39' shape=() dtype=float32>,
#  'ancestor1_id_len': <tf.Tensor 'DecodeCSV:40' shape=() dtype=float32>,
#  'ancestor1_class_len': <tf.Tensor 'DecodeCSV:41' shape=() dtype=float32>,
#  'ancestor1_no_children': <tf.Tensor 'DecodeCSV:42' shape=() dtype=float32>,
#  'ancestor1_text_len': <tf.Tensor 'DecodeCSV:43' shape=() dtype=float32>,
#  'ancestor2_depth': <tf.Tensor 'DecodeCSV:44' shape=() dtype=float32>,
#  'ancestor2_sibling_pos': <tf.Tensor 'DecodeCSV:45' shape=() dtype=float32>,
#  'ancestor2_no_classes': <tf.Tensor 'DecodeCSV:46' shape=() dtype=float32>,
#  'ancestor2_id_len': <tf.Tensor 'DecodeCSV:47' shape=() dtype=float32>,
#  'ancestor2_class_len': <tf.Tensor 'DecodeCSV:48' shape=() dtype=float32>,
#  'ancestor2_no_children': <tf.Tensor 'DecodeCSV:49' shape=() dtype=float32>,
#  'ancestor2_text_len': <tf.Tensor 'DecodeCSV:50' shape=() dtype=float32>,
#  'ancestor3_depth': <tf.Tensor 'DecodeCSV:51' shape=() dtype=float32>,
#  'ancestor3_sibling_pos': <tf.Tensor 'DecodeCSV:52' shape=() dtype=float32>,
#  'ancestor3_no_classes': <tf.Tensor 'DecodeCSV:53' shape=() dtype=float32>,
#  'ancestor3_id_len': <tf.Tensor 'DecodeCSV:54' shape=() dtype=float32>,
#  'ancestor3_class_len': <tf.Tensor 'DecodeCSV:55' shape=() dtype=float32>,
#  'ancestor3_no_children': <tf.Tensor 'DecodeCSV:56' shape=() dtype=float32>,
#  'ancestor3_text_len': <tf.Tensor 'DecodeCSV:57' shape=() dtype=float32>,
#  'ancestor4_depth': <tf.Tensor 'DecodeCSV:58' shape=() dtype=float32>,
#  'ancestor4_sibling_pos': <tf.Tensor 'DecodeCSV:59' shape=() dtype=float32>,
#  'ancestor4_no_classes': <tf.Tensor 'DecodeCSV:60' shape=() dtype=float32>,
#  'ancestor4_id_len': <tf.Tensor 'DecodeCSV:61' shape=() dtype=float32>,
#  'ancestor4_class_len': <tf.Tensor 'DecodeCSV:62' shape=() dtype=float32>,
#  'ancestor4_no_children': <tf.Tensor 'DecodeCSV:63' shape=() dtype=float32>,
#  'ancestor4_text_len': <tf.Tensor 'DecodeCSV:64' shape=() dtype=float32>,
#  'ancestor5_depth': <tf.Tensor 'DecodeCSV:65' shape=() dtype=float32>,
#  'ancestor5_sibling_pos': <tf.Tensor 'DecodeCSV:66' shape=() dtype=float32>,
#  'ancestor5_no_classes': <tf.Tensor 'DecodeCSV:67' shape=() dtype=float32>,
#  'ancestor5_id_len': <tf.Tensor 'DecodeCSV:68' shape=() dtype=float32>,
#  'ancestor5_class_len': <tf.Tensor 'DecodeCSV:69' shape=() dtype=float32>,
#  'ancestor5_no_children': <tf.Tensor 'DecodeCSV:70' shape=() dtype=float32>,
#  'ancestor5_text_len': <tf.Tensor 'DecodeCSV:71' shape=() dtype=float32>,
#  'path': <tf.Tensor 'DecodeCSV:72' shape=() dtype=string>,
#  'url': <tf.Tensor 'DecodeCSV:73' shape=() dtype=string>,
#  'descendant1_tags_a': <tf.Tensor 'DecodeCSV:74' shape=() dtype=float32>,
#  'descendant1_tags_abbr': <tf.Tensor 'DecodeCSV:75' shape=() dtype=float32>,
#  'descendant1_tags_acronym': <tf.Tensor 'DecodeCSV:76' shape=() dtype=float32>,
#  'descendant1_tags_address': <tf.Tensor 'DecodeCSV:77' shape=() dtype=float32>,
#  'descendant1_tags_ahref': <tf.Tensor 'DecodeCSV:78' shape=() dtype=float32>,
#  'descendant1_tags_align': <tf.Tensor 'DecodeCSV:79' shape=() dtype=float32>,
#  'descendant1_tags_applet': <tf.Tensor 'DecodeCSV:80' shape=() dtype=float32>,
#  'descendant1_tags_area': <tf.Tensor 'DecodeCSV:81' shape=() dtype=float32>,
#  'descendant1_tags_artbody': <tf.Tensor 'DecodeCSV:82' shape=() dtype=float32>,
#  'descendant1_tags_arybhatt': <tf.Tensor 'DecodeCSV:83' shape=() dtype=float32>,
#  'descendant1_tags_asc': <tf.Tensor 'DecodeCSV:84' shape=() dtype=float32>,
#  'descendant1_tags_author': <tf.Tensor 'DecodeCSV:85' shape=() dtype=float32>,
#  'descendant1_tags_b': <tf.Tensor 'DecodeCSV:86' shape=() dtype=float32>,
#  'descendant1_tags_base': <tf.Tensor 'DecodeCSV:87' shape=() dtype=float32>,
#  'descendant1_tags_basefont': <tf.Tensor 'DecodeCSV:88' shape=() dtype=float32>,
#  'descendant1_tags_be': <tf.Tensor 'DecodeCSV:89' shape=() dtype=float32>,
#  'descendant1_tags_beginlock': <tf.Tensor 'DecodeCSV:90' shape=() dtype=float32>,
#  'descendant1_tags_bgsound': <tf.Tensor 'DecodeCSV:91' shape=() dtype=float32>,
#  'descendant1_tags_big': <tf.Tensor 'DecodeCSV:92' shape=() dtype=float32>,
#  'descendant1_tags_blink': <tf.Tensor 'DecodeCSV:93' shape=() dtype=float32>,
#  'descendant1_tags_blockqoute': <tf.Tensor 'DecodeCSV:94' shape=() dtype=float32>,
#  'descendant1_tags_blockquote': <tf.Tensor 'DecodeCSV:95' shape=() dtype=float32>,
#  'descendant1_tags_body': <tf.Tensor 'DecodeCSV:96' shape=() dtype=float32>,
#  'descendant1_tags_br': <tf.Tensor 'DecodeCSV:97' shape=() dtype=float32>,
#  'descendant1_tags_button': <tf.Tensor 'DecodeCSV:98' shape=() dtype=float32>,
#  'descendant1_tags_caption': <tf.Tensor 'DecodeCSV:99' shape=() dtype=float32>,
#  'descendant1_tags_center': <tf.Tensor 'DecodeCSV:100' shape=() dtype=float32>,
#  'descendant1_tags_cite': <tf.Tensor 'DecodeCSV:101' shape=() dtype=float32>,
#  'descendant1_tags_city': <tf.Tensor 'DecodeCSV:102' shape=() dtype=float32>,
#  'descendant1_tags_code': <tf.Tensor 'DecodeCSV:103' shape=() dtype=float32>,
#  'descendant1_tags_col': <tf.Tensor 'DecodeCSV:104' shape=() dtype=float32>,
#  'descendant1_tags_colgroup': <tf.Tensor 'DecodeCSV:105' shape=() dtype=float32>,
#  'descendant1_tags_companyquotes': <tf.Tensor 'DecodeCSV:106' shape=() dtype=float32>,
#  'descendant1_tags_container': <tf.Tensor 'DecodeCSV:107' shape=() dtype=float32>,
#  'descendant1_tags_content': <tf.Tensor 'DecodeCSV:108' shape=() dtype=float32>,
#  'descendant1_tags_content_area': <tf.Tensor 'DecodeCSV:109' shape=() dtype=float32>,
#  'descendant1_tags_content_footer': <tf.Tensor 'DecodeCSV:110' shape=() dtype=float32>,
#  'descendant1_tags_country-region': <tf.Tensor 'DecodeCSV:111' shape=() dtype=float32>,
#  'descendant1_tags_csaction': <tf.Tensor 'DecodeCSV:112' shape=() dtype=float32>,
#  'descendant1_tags_csactiondict': <tf.Tensor 'DecodeCSV:113' shape=() dtype=float32>,
#  'descendant1_tags_csactions': <tf.Tensor 'DecodeCSV:114' shape=() dtype=float32>,
#  'descendant1_tags_csimport': <tf.Tensor 'DecodeCSV:115' shape=() dtype=float32>,
#  'descendant1_tags_csobj': <tf.Tensor 'DecodeCSV:116' shape=() dtype=float32>,
#  'descendant1_tags_csscriptdict': <tf.Tensor 'DecodeCSV:117' shape=() dtype=float32>,
#  'descendant1_tags_cut': <tf.Tensor 'DecodeCSV:118' shape=() dtype=float32>,
#  'descendant1_tags_dd': <tf.Tensor 'DecodeCSV:119' shape=() dtype=float32>,
#  'descendant1_tags_deadilnk': <tf.Tensor 'DecodeCSV:120' shape=() dtype=float32>,
#  'descendant1_tags_defanged_meta': <tf.Tensor 'DecodeCSV:121' shape=() dtype=float32>,
#  'descendant1_tags_del': <tf.Tensor 'DecodeCSV:122' shape=() dtype=float32>,
#  'descendant1_tags_dfn': <tf.Tensor 'DecodeCSV:123' shape=() dtype=float32>,
#  'descendant1_tags_dir': <tf.Tensor 'DecodeCSV:124' shape=() dtype=float32>,
#  'descendant1_tags_displayname': <tf.Tensor 'DecodeCSV:125' shape=() dtype=float32>,
#  'descendant1_tags_div': <tf.Tensor 'DecodeCSV:126' shape=() dtype=float32>,
#  'descendant1_tags_dl': <tf.Tensor 'DecodeCSV:127' shape=() dtype=float32>,
#  'descendant1_tags_dnt': <tf.Tensor 'DecodeCSV:128' shape=() dtype=float32>,
#  'descendant1_tags_dt': <tf.Tensor 'DecodeCSV:129' shape=() dtype=float32>,
#  'descendant1_tags_em': <tf.Tensor 'DecodeCSV:130' shape=() dtype=float32>,
#  'descendant1_tags_embed': <tf.Tensor 'DecodeCSV:131' shape=() dtype=float32>,
#  'descendant1_tags_end': <tf.Tensor 'DecodeCSV:132' shape=() dtype=float32>,
#  'descendant1_tags_endlock': <tf.Tensor 'DecodeCSV:133' shape=() dtype=float32>,
#  'descendant1_tags_epabreadcrumbs': <tf.Tensor 'DecodeCSV:134' shape=() dtype=float32>,
#  'descendant1_tags_epadateurl': <tf.Tensor 'DecodeCSV:135' shape=() dtype=float32>,
#  'descendant1_tags_epasidebar': <tf.Tensor 'DecodeCSV:136' shape=() dtype=float32>,
#  'descendant1_tags_f': <tf.Tensor 'DecodeCSV:137' shape=() dtype=float32>,
#  'descendant1_tags_fieldset': <tf.Tensor 'DecodeCSV:138' shape=() dtype=float32>,
#  'descendant1_tags_font': <tf.Tensor 'DecodeCSV:139' shape=() dtype=float32>,
#  'descendant1_tags_form': <tf.Tensor 'DecodeCSV:140' shape=() dtype=float32>,
#  'descendant1_tags_formulas': <tf.Tensor 'DecodeCSV:141' shape=() dtype=float32>,
#  'descendant1_tags_garden01': <tf.Tensor 'DecodeCSV:142' shape=() dtype=float32>,
#  'descendant1_tags_gc3': <tf.Tensor 'DecodeCSV:143' shape=() dtype=float32>,
#  'descendant1_tags_h1': <tf.Tensor 'DecodeCSV:144' shape=() dtype=float32>,
#  'descendant1_tags_h2': <tf.Tensor 'DecodeCSV:145' shape=() dtype=float32>,
#  'descendant1_tags_h3': <tf.Tensor 'DecodeCSV:146' shape=() dtype=float32>,
#  'descendant1_tags_h4': <tf.Tensor 'DecodeCSV:147' shape=() dtype=float32>,
#  'descendant1_tags_h5': <tf.Tensor 'DecodeCSV:148' shape=() dtype=float32>,
#  'descendant1_tags_h6': <tf.Tensor 'DecodeCSV:149' shape=() dtype=float32>,
#  'descendant1_tags_h7': <tf.Tensor 'DecodeCSV:150' shape=() dtype=float32>,
#  'descendant1_tags_header': <tf.Tensor 'DecodeCSV:151' shape=() dtype=float32>,
#  'descendant1_tags_headline': <tf.Tensor 'DecodeCSV:152' shape=() dtype=float32>,
#  'descendant1_tags_hp': <tf.Tensor 'DecodeCSV:153' shape=() dtype=float32>,
#  'descendant1_tags_hr': <tf.Tensor 'DecodeCSV:154' shape=() dtype=float32>,
#  'descendant1_tags_html': <tf.Tensor 'DecodeCSV:155' shape=() dtype=float32>,
#  'descendant1_tags_html_comment': <tf.Tensor 'DecodeCSV:156' shape=() dtype=float32>,
#  'descendant1_tags_http-equiv': <tf.Tensor 'DecodeCSV:157' shape=() dtype=float32>,
#  'descendant1_tags_http:': <tf.Tensor 'DecodeCSV:158' shape=() dtype=float32>,
#  'descendant1_tags_i': <tf.Tensor 'DecodeCSV:159' shape=() dtype=float32>,
#  'descendant1_tags_id': <tf.Tensor 'DecodeCSV:160' shape=() dtype=float32>,
#  'descendant1_tags_if': <tf.Tensor 'DecodeCSV:161' shape=() dtype=float32>,
#  'descendant1_tags_iframe': <tf.Tensor 'DecodeCSV:162' shape=() dtype=float32>,
#  'descendant1_tags_ilayer': <tf.Tensor 'DecodeCSV:163' shape=() dtype=float32>,
#  'descendant1_tags_image': <tf.Tensor 'DecodeCSV:164' shape=() dtype=float32>,
#  'descendant1_tags_imagedata': <tf.Tensor 'DecodeCSV:165' shape=() dtype=float32>,
#  'descendant1_tags_img': <tf.Tensor 'DecodeCSV:166' shape=() dtype=float32>,
#  'descendant1_tags_inactivescript': <tf.Tensor 'DecodeCSV:167' shape=() dtype=float32>,
#  'descendant1_tags_input': <tf.Tensor 'DecodeCSV:168' shape=() dtype=float32>,
#  'descendant1_tags_intl_links': <tf.Tensor 'DecodeCSV:169' shape=() dtype=float32>,
#  'descendant1_tags_l': <tf.Tensor 'DecodeCSV:170' shape=() dtype=float32>,
#  'descendant1_tags_l1': <tf.Tensor 'DecodeCSV:171' shape=() dtype=float32>,
#  'descendant1_tags_l10': <tf.Tensor 'DecodeCSV:172' shape=() dtype=float32>,
#  'descendant1_tags_l11': <tf.Tensor 'DecodeCSV:173' shape=() dtype=float32>,
#  'descendant1_tags_l12': <tf.Tensor 'DecodeCSV:174' shape=() dtype=float32>,
#  'descendant1_tags_l2': <tf.Tensor 'DecodeCSV:175' shape=() dtype=float32>,
#  'descendant1_tags_l3': <tf.Tensor 'DecodeCSV:176' shape=() dtype=float32>,
#  'descendant1_tags_l4': <tf.Tensor 'DecodeCSV:177' shape=() dtype=float32>,
#  'descendant1_tags_l5': <tf.Tensor 'DecodeCSV:178' shape=() dtype=float32>,
#  'descendant1_tags_l6': <tf.Tensor 'DecodeCSV:179' shape=() dtype=float32>,
#  'descendant1_tags_l7': <tf.Tensor 'DecodeCSV:180' shape=() dtype=float32>,
#  'descendant1_tags_l8': <tf.Tensor 'DecodeCSV:181' shape=() dtype=float32>,
#  'descendant1_tags_l9': <tf.Tensor 'DecodeCSV:182' shape=() dtype=float32>,
#  'descendant1_tags_label': <tf.Tensor 'DecodeCSV:183' shape=() dtype=float32>,
#  'descendant1_tags_layer': <tf.Tensor 'DecodeCSV:184' shape=() dtype=float32>,
#  'descendant1_tags_left': <tf.Tensor 'DecodeCSV:185' shape=() dtype=float32>,
#  'descendant1_tags_left_nav': <tf.Tensor 'DecodeCSV:186' shape=() dtype=float32>,
#  'descendant1_tags_legend': <tf.Tensor 'DecodeCSV:187' shape=() dtype=float32>,
#  'descendant1_tags_li': <tf.Tensor 'DecodeCSV:188' shape=() dtype=float32>,
#  'descendant1_tags_link': <tf.Tensor 'DecodeCSV:189' shape=() dtype=float32>,
#  'descendant1_tags_lock': <tf.Tensor 'DecodeCSV:190' shape=() dtype=float32>,
#  'descendant1_tags_lscontent': <tf.Tensor 'DecodeCSV:191' shape=() dtype=float32>,
#  'descendant1_tags_mainorarchivepage': <tf.Tensor 'DecodeCSV:192' shape=() dtype=float32>,
#  'descendant1_tags_map': <tf.Tensor 'DecodeCSV:193' shape=() dtype=float32>,
#  'descendant1_tags_marquee': <tf.Tensor 'DecodeCSV:194' shape=() dtype=float32>,
#  'descendant1_tags_menu': <tf.Tensor 'DecodeCSV:195' shape=() dtype=float32>,
#  'descendant1_tags_meta': <tf.Tensor 'DecodeCSV:196' shape=() dtype=float32>,
#  'descendant1_tags_newselement': <tf.Tensor 'DecodeCSV:197' shape=() dtype=float32>,
#  'descendant1_tags_nitf': <tf.Tensor 'DecodeCSV:198' shape=() dtype=float32>,
#  'descendant1_tags_nobr': <tf.Tensor 'DecodeCSV:199' shape=() dtype=float32>,
#  'descendant1_tags_noedit': <tf.Tensor 'DecodeCSV:200' shape=() dtype=float32>,
#  'descendant1_tags_noindex': <tf.Tensor 'DecodeCSV:201' shape=() dtype=float32>,
#  'descendant1_tags_nolayer': <tf.Tensor 'DecodeCSV:202' shape=() dtype=float32>,
#  'descendant1_tags_noscript': <tf.Tensor 'DecodeCSV:203' shape=() dtype=float32>,
#  'descendant1_tags_nr': <tf.Tensor 'DecodeCSV:204' shape=() dtype=float32>,
#  'descendant1_tags_object': <tf.Tensor 'DecodeCSV:205' shape=() dtype=float32>,
#  'descendant1_tags_ol': <tf.Tensor 'DecodeCSV:206' shape=() dtype=float32>,
#  'descendant1_tags_optgroup': <tf.Tensor 'DecodeCSV:207' shape=() dtype=float32>,
#  'descendant1_tags_option': <tf.Tensor 'DecodeCSV:208' shape=() dtype=float32>,
#  'descendant1_tags_p': <tf.Tensor 'DecodeCSV:209' shape=() dtype=float32>,
#  'descendant1_tags_page': <tf.Tensor 'DecodeCSV:210' shape=() dtype=float32>,
#  'descendant1_tags_param': <tf.Tensor 'DecodeCSV:211' shape=() dtype=float32>,
#  'descendant1_tags_path': <tf.Tensor 'DecodeCSV:212' shape=() dtype=float32>,
#  'descendant1_tags_place': <tf.Tensor 'DecodeCSV:213' shape=() dtype=float32>,
#  'descendant1_tags_placename': <tf.Tensor 'DecodeCSV:214' shape=() dtype=float32>,
#  'descendant1_tags_placetype': <tf.Tensor 'DecodeCSV:215' shape=() dtype=float32>,
#  'descendant1_tags_pre': <tf.Tensor 'DecodeCSV:216' shape=() dtype=float32>,
#  'descendant1_tags_promo': <tf.Tensor 'DecodeCSV:217' shape=() dtype=float32>,
#  'descendant1_tags_q': <tf.Tensor 'DecodeCSV:218' shape=() dtype=float32>,
#  'descendant1_tags_removeforprint': <tf.Tensor 'DecodeCSV:219' shape=() dtype=float32>,
#  'descendant1_tags_s': <tf.Tensor 'DecodeCSV:220' shape=() dtype=float32>,
#  'descendant1_tags_script': <tf.Tensor 'DecodeCSV:221' shape=() dtype=float32>,
#  'descendant1_tags_select': <tf.Tensor 'DecodeCSV:222' shape=() dtype=float32>,
#  'descendant1_tags_shape': <tf.Tensor 'DecodeCSV:223' shape=() dtype=float32>,
#  'descendant1_tags_shapetype': <tf.Tensor 'DecodeCSV:224' shape=() dtype=float32>,
#  'descendant1_tags_small': <tf.Tensor 'DecodeCSV:225' shape=() dtype=float32>,
#  'descendant1_tags_smarttagtype': <tf.Tensor 'DecodeCSV:226' shape=() dtype=float32>,
#  'descendant1_tags_smile': <tf.Tensor 'DecodeCSV:227' shape=() dtype=float32>,
#  'descendant1_tags_spacer': <tf.Tensor 'DecodeCSV:228' shape=() dtype=float32>,
#  'descendant1_tags_span': <tf.Tensor 'DecodeCSV:229' shape=() dtype=float32>,
#  'descendant1_tags_state': <tf.Tensor 'DecodeCSV:230' shape=() dtype=float32>,
#  'descendant1_tags_storysumm': <tf.Tensor 'DecodeCSV:231' shape=() dtype=float32>,
#  'descendant1_tags_stroke': <tf.Tensor 'DecodeCSV:232' shape=() dtype=float32>,
#  'descendant1_tags_strong': <tf.Tensor 'DecodeCSV:233' shape=() dtype=float32>,
#  'descendant1_tags_style': <tf.Tensor 'DecodeCSV:234' shape=() dtype=float32>,
#  'descendant1_tags_sub': <tf.Tensor 'DecodeCSV:235' shape=() dtype=float32>,
#  'descendant1_tags_subscribe': <tf.Tensor 'DecodeCSV:236' shape=() dtype=float32>,
#  'descendant1_tags_sup': <tf.Tensor 'DecodeCSV:237' shape=() dtype=float32>,
#  'descendant1_tags_table': <tf.Tensor 'DecodeCSV:238' shape=() dtype=float32>,
#  'descendant1_tags_tbody': <tf.Tensor 'DecodeCSV:239' shape=() dtype=float32>,
#  'descendant1_tags_td': <tf.Tensor 'DecodeCSV:240' shape=() dtype=float32>,
#  'descendant1_tags_text': <tf.Tensor 'DecodeCSV:241' shape=() dtype=float32>,
#  'descendant1_tags_textarea': <tf.Tensor 'DecodeCSV:242' shape=() dtype=float32>,
#  'descendant1_tags_textbox': <tf.Tensor 'DecodeCSV:243' shape=() dtype=float32>,
#  'descendant1_tags_th': <tf.Tensor 'DecodeCSV:244' shape=() dtype=float32>,
#  'descendant1_tags_thead': <tf.Tensor 'DecodeCSV:245' shape=() dtype=float32>,
#  'descendant1_tags_title': <tf.Tensor 'DecodeCSV:246' shape=() dtype=float32>,
#  'descendant1_tags_tr': <tf.Tensor 'DecodeCSV:247' shape=() dtype=float32>,
#  'descendant1_tags_tt': <tf.Tensor 'DecodeCSV:248' shape=() dtype=float32>,
#  'descendant1_tags_u': <tf.Tensor 'DecodeCSV:249' shape=() dtype=float32>,
#  'descendant1_tags_ul': <tf.Tensor 'DecodeCSV:250' shape=() dtype=float32>,
#  'descendant1_tags_var': <tf.Tensor 'DecodeCSV:251' shape=() dtype=float32>,
#  'descendant1_tags_verdana': <tf.Tensor 'DecodeCSV:252' shape=() dtype=float32>,
#  'descendant1_tags_wbr': <tf.Tensor 'DecodeCSV:253' shape=() dtype=float32>,
#  'descendant1_tags_wsj': <tf.Tensor 'DecodeCSV:254' shape=() dtype=float32>,
#  'descendant2_tags_a': <tf.Tensor 'DecodeCSV:255' shape=() dtype=float32>,
#  'descendant2_tags_abbr': <tf.Tensor 'DecodeCSV:256' shape=() dtype=float32>,
#  'descendant2_tags_acronym': <tf.Tensor 'DecodeCSV:257' shape=() dtype=float32>,
#  'descendant2_tags_address': <tf.Tensor 'DecodeCSV:258' shape=() dtype=float32>,
#  'descendant2_tags_ahref': <tf.Tensor 'DecodeCSV:259' shape=() dtype=float32>,
#  'descendant2_tags_align': <tf.Tensor 'DecodeCSV:260' shape=() dtype=float32>,
#  'descendant2_tags_applet': <tf.Tensor 'DecodeCSV:261' shape=() dtype=float32>,
#  'descendant2_tags_area': <tf.Tensor 'DecodeCSV:262' shape=() dtype=float32>,
#  'descendant2_tags_artbody': <tf.Tensor 'DecodeCSV:263' shape=() dtype=float32>,
#  'descendant2_tags_arybhatt': <tf.Tensor 'DecodeCSV:264' shape=() dtype=float32>,
#  'descendant2_tags_asc': <tf.Tensor 'DecodeCSV:265' shape=() dtype=float32>,
#  'descendant2_tags_author': <tf.Tensor 'DecodeCSV:266' shape=() dtype=float32>,
#  'descendant2_tags_b': <tf.Tensor 'DecodeCSV:267' shape=() dtype=float32>,
#  'descendant2_tags_base': <tf.Tensor 'DecodeCSV:268' shape=() dtype=float32>,
#  'descendant2_tags_basefont': <tf.Tensor 'DecodeCSV:269' shape=() dtype=float32>,
#  'descendant2_tags_be': <tf.Tensor 'DecodeCSV:270' shape=() dtype=float32>,
#  'descendant2_tags_beginlock': <tf.Tensor 'DecodeCSV:271' shape=() dtype=float32>,
#  'descendant2_tags_bgsound': <tf.Tensor 'DecodeCSV:272' shape=() dtype=float32>,
#  'descendant2_tags_big': <tf.Tensor 'DecodeCSV:273' shape=() dtype=float32>,
#  'descendant2_tags_blink': <tf.Tensor 'DecodeCSV:274' shape=() dtype=float32>,
#  'descendant2_tags_blockqoute': <tf.Tensor 'DecodeCSV:275' shape=() dtype=float32>,
#  'descendant2_tags_blockquote': <tf.Tensor 'DecodeCSV:276' shape=() dtype=float32>,
#  'descendant2_tags_body': <tf.Tensor 'DecodeCSV:277' shape=() dtype=float32>,
#  'descendant2_tags_br': <tf.Tensor 'DecodeCSV:278' shape=() dtype=float32>,
#  'descendant2_tags_button': <tf.Tensor 'DecodeCSV:279' shape=() dtype=float32>,
#  'descendant2_tags_caption': <tf.Tensor 'DecodeCSV:280' shape=() dtype=float32>,
#  'descendant2_tags_center': <tf.Tensor 'DecodeCSV:281' shape=() dtype=float32>,
#  'descendant2_tags_cite': <tf.Tensor 'DecodeCSV:282' shape=() dtype=float32>,
#  'descendant2_tags_city': <tf.Tensor 'DecodeCSV:283' shape=() dtype=float32>,
#  'descendant2_tags_code': <tf.Tensor 'DecodeCSV:284' shape=() dtype=float32>,
#  'descendant2_tags_col': <tf.Tensor 'DecodeCSV:285' shape=() dtype=float32>,
#  'descendant2_tags_colgroup': <tf.Tensor 'DecodeCSV:286' shape=() dtype=float32>,
#  'descendant2_tags_companyquotes': <tf.Tensor 'DecodeCSV:287' shape=() dtype=float32>,
#  'descendant2_tags_container': <tf.Tensor 'DecodeCSV:288' shape=() dtype=float32>,
#  'descendant2_tags_content': <tf.Tensor 'DecodeCSV:289' shape=() dtype=float32>,
#  'descendant2_tags_content_area': <tf.Tensor 'DecodeCSV:290' shape=() dtype=float32>,
#  'descendant2_tags_content_footer': <tf.Tensor 'DecodeCSV:291' shape=() dtype=float32>,
#  'descendant2_tags_country-region': <tf.Tensor 'DecodeCSV:292' shape=() dtype=float32>,
#  'descendant2_tags_csaction': <tf.Tensor 'DecodeCSV:293' shape=() dtype=float32>,
#  'descendant2_tags_csactiondict': <tf.Tensor 'DecodeCSV:294' shape=() dtype=float32>,
#  'descendant2_tags_csactions': <tf.Tensor 'DecodeCSV:295' shape=() dtype=float32>,
#  'descendant2_tags_csimport': <tf.Tensor 'DecodeCSV:296' shape=() dtype=float32>,
#  'descendant2_tags_csobj': <tf.Tensor 'DecodeCSV:297' shape=() dtype=float32>,
#  'descendant2_tags_csscriptdict': <tf.Tensor 'DecodeCSV:298' shape=() dtype=float32>,
#  'descendant2_tags_cut': <tf.Tensor 'DecodeCSV:299' shape=() dtype=float32>,
#  'descendant2_tags_dd': <tf.Tensor 'DecodeCSV:300' shape=() dtype=float32>,
#  'descendant2_tags_deadilnk': <tf.Tensor 'DecodeCSV:301' shape=() dtype=float32>,
#  'descendant2_tags_defanged_meta': <tf.Tensor 'DecodeCSV:302' shape=() dtype=float32>,
#  'descendant2_tags_del': <tf.Tensor 'DecodeCSV:303' shape=() dtype=float32>,
#  'descendant2_tags_dfn': <tf.Tensor 'DecodeCSV:304' shape=() dtype=float32>,
#  'descendant2_tags_dir': <tf.Tensor 'DecodeCSV:305' shape=() dtype=float32>,
#  'descendant2_tags_displayname': <tf.Tensor 'DecodeCSV:306' shape=() dtype=float32>,
#  'descendant2_tags_div': <tf.Tensor 'DecodeCSV:307' shape=() dtype=float32>,
#  'descendant2_tags_dl': <tf.Tensor 'DecodeCSV:308' shape=() dtype=float32>,
#  'descendant2_tags_dnt': <tf.Tensor 'DecodeCSV:309' shape=() dtype=float32>,
#  'descendant2_tags_dt': <tf.Tensor 'DecodeCSV:310' shape=() dtype=float32>,
#  'descendant2_tags_em': <tf.Tensor 'DecodeCSV:311' shape=() dtype=float32>,
#  'descendant2_tags_embed': <tf.Tensor 'DecodeCSV:312' shape=() dtype=float32>,
#  'descendant2_tags_end': <tf.Tensor 'DecodeCSV:313' shape=() dtype=float32>,
#  'descendant2_tags_endlock': <tf.Tensor 'DecodeCSV:314' shape=() dtype=float32>,
#  'descendant2_tags_epabreadcrumbs': <tf.Tensor 'DecodeCSV:315' shape=() dtype=float32>,
#  'descendant2_tags_epadateurl': <tf.Tensor 'DecodeCSV:316' shape=() dtype=float32>,
#  'descendant2_tags_epasidebar': <tf.Tensor 'DecodeCSV:317' shape=() dtype=float32>,
#  'descendant2_tags_f': <tf.Tensor 'DecodeCSV:318' shape=() dtype=float32>,
#  'descendant2_tags_fieldset': <tf.Tensor 'DecodeCSV:319' shape=() dtype=float32>,
#  'descendant2_tags_font': <tf.Tensor 'DecodeCSV:320' shape=() dtype=float32>,
#  'descendant2_tags_form': <tf.Tensor 'DecodeCSV:321' shape=() dtype=float32>,
#  'descendant2_tags_formulas': <tf.Tensor 'DecodeCSV:322' shape=() dtype=float32>,
#  'descendant2_tags_garden01': <tf.Tensor 'DecodeCSV:323' shape=() dtype=float32>,
#  'descendant2_tags_gc3': <tf.Tensor 'DecodeCSV:324' shape=() dtype=float32>,
#  'descendant2_tags_h1': <tf.Tensor 'DecodeCSV:325' shape=() dtype=float32>,
#  'descendant2_tags_h2': <tf.Tensor 'DecodeCSV:326' shape=() dtype=float32>,
#  'descendant2_tags_h3': <tf.Tensor 'DecodeCSV:327' shape=() dtype=float32>,
#  'descendant2_tags_h4': <tf.Tensor 'DecodeCSV:328' shape=() dtype=float32>,
#  'descendant2_tags_h5': <tf.Tensor 'DecodeCSV:329' shape=() dtype=float32>,
#  'descendant2_tags_h6': <tf.Tensor 'DecodeCSV:330' shape=() dtype=float32>,
#  'descendant2_tags_h7': <tf.Tensor 'DecodeCSV:331' shape=() dtype=float32>,
#  'descendant2_tags_header': <tf.Tensor 'DecodeCSV:332' shape=() dtype=float32>,
#  'descendant2_tags_headline': <tf.Tensor 'DecodeCSV:333' shape=() dtype=float32>,
#  'descendant2_tags_hp': <tf.Tensor 'DecodeCSV:334' shape=() dtype=float32>,
#  'descendant2_tags_hr': <tf.Tensor 'DecodeCSV:335' shape=() dtype=float32>,
#  'descendant2_tags_html_comment': <tf.Tensor 'DecodeCSV:336' shape=() dtype=float32>,
#  'descendant2_tags_http-equiv': <tf.Tensor 'DecodeCSV:337' shape=() dtype=float32>,
#  'descendant2_tags_http:': <tf.Tensor 'DecodeCSV:338' shape=() dtype=float32>,
#  'descendant2_tags_i': <tf.Tensor 'DecodeCSV:339' shape=() dtype=float32>,
#  'descendant2_tags_id': <tf.Tensor 'DecodeCSV:340' shape=() dtype=float32>,
#  'descendant2_tags_if': <tf.Tensor 'DecodeCSV:341' shape=() dtype=float32>,
#  'descendant2_tags_iframe': <tf.Tensor 'DecodeCSV:342' shape=() dtype=float32>,
#  'descendant2_tags_ilayer': <tf.Tensor 'DecodeCSV:343' shape=() dtype=float32>,
#  'descendant2_tags_image': <tf.Tensor 'DecodeCSV:344' shape=() dtype=float32>,
#  'descendant2_tags_imagedata': <tf.Tensor 'DecodeCSV:345' shape=() dtype=float32>,
#  'descendant2_tags_img': <tf.Tensor 'DecodeCSV:346' shape=() dtype=float32>,
#  'descendant2_tags_inactivescript': <tf.Tensor 'DecodeCSV:347' shape=() dtype=float32>,
#  'descendant2_tags_input': <tf.Tensor 'DecodeCSV:348' shape=() dtype=float32>,
#  'descendant2_tags_intl_links': <tf.Tensor 'DecodeCSV:349' shape=() dtype=float32>,
#  'descendant2_tags_l': <tf.Tensor 'DecodeCSV:350' shape=() dtype=float32>,
#  'descendant2_tags_l1': <tf.Tensor 'DecodeCSV:351' shape=() dtype=float32>,
#  'descendant2_tags_l10': <tf.Tensor 'DecodeCSV:352' shape=() dtype=float32>,
#  'descendant2_tags_l11': <tf.Tensor 'DecodeCSV:353' shape=() dtype=float32>,
#  'descendant2_tags_l12': <tf.Tensor 'DecodeCSV:354' shape=() dtype=float32>,
#  'descendant2_tags_l2': <tf.Tensor 'DecodeCSV:355' shape=() dtype=float32>,
#  'descendant2_tags_l3': <tf.Tensor 'DecodeCSV:356' shape=() dtype=float32>,
#  'descendant2_tags_l4': <tf.Tensor 'DecodeCSV:357' shape=() dtype=float32>,
#  'descendant2_tags_l5': <tf.Tensor 'DecodeCSV:358' shape=() dtype=float32>,
#  'descendant2_tags_l6': <tf.Tensor 'DecodeCSV:359' shape=() dtype=float32>,
#  'descendant2_tags_l7': <tf.Tensor 'DecodeCSV:360' shape=() dtype=float32>,
#  'descendant2_tags_l8': <tf.Tensor 'DecodeCSV:361' shape=() dtype=float32>,
#  'descendant2_tags_l9': <tf.Tensor 'DecodeCSV:362' shape=() dtype=float32>,
#  'descendant2_tags_label': <tf.Tensor 'DecodeCSV:363' shape=() dtype=float32>,
#  'descendant2_tags_layer': <tf.Tensor 'DecodeCSV:364' shape=() dtype=float32>,
#  'descendant2_tags_left': <tf.Tensor 'DecodeCSV:365' shape=() dtype=float32>,
#  'descendant2_tags_left_nav': <tf.Tensor 'DecodeCSV:366' shape=() dtype=float32>,
#  'descendant2_tags_legend': <tf.Tensor 'DecodeCSV:367' shape=() dtype=float32>,
#  'descendant2_tags_li': <tf.Tensor 'DecodeCSV:368' shape=() dtype=float32>,
#  'descendant2_tags_link': <tf.Tensor 'DecodeCSV:369' shape=() dtype=float32>,
#  'descendant2_tags_lock': <tf.Tensor 'DecodeCSV:370' shape=() dtype=float32>,
#  'descendant2_tags_lscontent': <tf.Tensor 'DecodeCSV:371' shape=() dtype=float32>,
#  'descendant2_tags_mainorarchivepage': <tf.Tensor 'DecodeCSV:372' shape=() dtype=float32>,
#  'descendant2_tags_map': <tf.Tensor 'DecodeCSV:373' shape=() dtype=float32>,
#  'descendant2_tags_marquee': <tf.Tensor 'DecodeCSV:374' shape=() dtype=float32>,
#  'descendant2_tags_menu': <tf.Tensor 'DecodeCSV:375' shape=() dtype=float32>,
#  'descendant2_tags_meta': <tf.Tensor 'DecodeCSV:376' shape=() dtype=float32>,
#  'descendant2_tags_newselement': <tf.Tensor 'DecodeCSV:377' shape=() dtype=float32>,
#  'descendant2_tags_nitf': <tf.Tensor 'DecodeCSV:378' shape=() dtype=float32>,
#  'descendant2_tags_nobr': <tf.Tensor 'DecodeCSV:379' shape=() dtype=float32>,
#  'descendant2_tags_noedit': <tf.Tensor 'DecodeCSV:380' shape=() dtype=float32>,
#  'descendant2_tags_noindex': <tf.Tensor 'DecodeCSV:381' shape=() dtype=float32>,
#  'descendant2_tags_nolayer': <tf.Tensor 'DecodeCSV:382' shape=() dtype=float32>,
#  'descendant2_tags_noscript': <tf.Tensor 'DecodeCSV:383' shape=() dtype=float32>,
#  'descendant2_tags_nr': <tf.Tensor 'DecodeCSV:384' shape=() dtype=float32>,
#  'descendant2_tags_object': <tf.Tensor 'DecodeCSV:385' shape=() dtype=float32>,
#  'descendant2_tags_ol': <tf.Tensor 'DecodeCSV:386' shape=() dtype=float32>,
#  'descendant2_tags_optgroup': <tf.Tensor 'DecodeCSV:387' shape=() dtype=float32>,
#  'descendant2_tags_option': <tf.Tensor 'DecodeCSV:388' shape=() dtype=float32>,
#  'descendant2_tags_p': <tf.Tensor 'DecodeCSV:389' shape=() dtype=float32>,
#  'descendant2_tags_page': <tf.Tensor 'DecodeCSV:390' shape=() dtype=float32>,
#  'descendant2_tags_param': <tf.Tensor 'DecodeCSV:391' shape=() dtype=float32>,
#  'descendant2_tags_path': <tf.Tensor 'DecodeCSV:392' shape=() dtype=float32>,
#  'descendant2_tags_place': <tf.Tensor 'DecodeCSV:393' shape=() dtype=float32>,
#  'descendant2_tags_placename': <tf.Tensor 'DecodeCSV:394' shape=() dtype=float32>,
#  'descendant2_tags_placetype': <tf.Tensor 'DecodeCSV:395' shape=() dtype=float32>,
#  'descendant2_tags_pre': <tf.Tensor 'DecodeCSV:396' shape=() dtype=float32>,
#  'descendant2_tags_promo': <tf.Tensor 'DecodeCSV:397' shape=() dtype=float32>,
#  'descendant2_tags_q': <tf.Tensor 'DecodeCSV:398' shape=() dtype=float32>,
#  'descendant2_tags_removeforprint': <tf.Tensor 'DecodeCSV:399' shape=() dtype=float32>,
#  'descendant2_tags_s': <tf.Tensor 'DecodeCSV:400' shape=() dtype=float32>,
#  'descendant2_tags_script': <tf.Tensor 'DecodeCSV:401' shape=() dtype=float32>,
#  'descendant2_tags_select': <tf.Tensor 'DecodeCSV:402' shape=() dtype=float32>,
#  'descendant2_tags_shape': <tf.Tensor 'DecodeCSV:403' shape=() dtype=float32>,
#  'descendant2_tags_shapetype': <tf.Tensor 'DecodeCSV:404' shape=() dtype=float32>,
#  'descendant2_tags_small': <tf.Tensor 'DecodeCSV:405' shape=() dtype=float32>,
#  'descendant2_tags_smarttagtype': <tf.Tensor 'DecodeCSV:406' shape=() dtype=float32>,
#  'descendant2_tags_smile': <tf.Tensor 'DecodeCSV:407' shape=() dtype=float32>,
#  'descendant2_tags_spacer': <tf.Tensor 'DecodeCSV:408' shape=() dtype=float32>,
#  'descendant2_tags_span': <tf.Tensor 'DecodeCSV:409' shape=() dtype=float32>,
#  'descendant2_tags_state': <tf.Tensor 'DecodeCSV:410' shape=() dtype=float32>,
#  'descendant2_tags_storysumm': <tf.Tensor 'DecodeCSV:411' shape=() dtype=float32>,
#  'descendant2_tags_stroke': <tf.Tensor 'DecodeCSV:412' shape=() dtype=float32>,
#  'descendant2_tags_strong': <tf.Tensor 'DecodeCSV:413' shape=() dtype=float32>,
#  'descendant2_tags_style': <tf.Tensor 'DecodeCSV:414' shape=() dtype=float32>,
#  'descendant2_tags_sub': <tf.Tensor 'DecodeCSV:415' shape=() dtype=float32>,
#  'descendant2_tags_subscribe': <tf.Tensor 'DecodeCSV:416' shape=() dtype=float32>,
#  'descendant2_tags_sup': <tf.Tensor 'DecodeCSV:417' shape=() dtype=float32>,
#  'descendant2_tags_table': <tf.Tensor 'DecodeCSV:418' shape=() dtype=float32>,
#  'descendant2_tags_tbody': <tf.Tensor 'DecodeCSV:419' shape=() dtype=float32>,
#  'descendant2_tags_td': <tf.Tensor 'DecodeCSV:420' shape=() dtype=float32>,
#  'descendant2_tags_text': <tf.Tensor 'DecodeCSV:421' shape=() dtype=float32>,
#  'descendant2_tags_textarea': <tf.Tensor 'DecodeCSV:422' shape=() dtype=float32>,
#  'descendant2_tags_textbox': <tf.Tensor 'DecodeCSV:423' shape=() dtype=float32>,
#  'descendant2_tags_th': <tf.Tensor 'DecodeCSV:424' shape=() dtype=float32>,
#  'descendant2_tags_thead': <tf.Tensor 'DecodeCSV:425' shape=() dtype=float32>,
#  'descendant2_tags_title': <tf.Tensor 'DecodeCSV:426' shape=() dtype=float32>,
#  'descendant2_tags_tr': <tf.Tensor 'DecodeCSV:427' shape=() dtype=float32>,
#  'descendant2_tags_tt': <tf.Tensor 'DecodeCSV:428' shape=() dtype=float32>,
#  'descendant2_tags_u': <tf.Tensor 'DecodeCSV:429' shape=() dtype=float32>,
#  'descendant2_tags_ul': <tf.Tensor 'DecodeCSV:430' shape=() dtype=float32>,
#  'descendant2_tags_var': <tf.Tensor 'DecodeCSV:431' shape=() dtype=float32>,
#  'descendant2_tags_verdana': <tf.Tensor 'DecodeCSV:432' shape=() dtype=float32>,
#  'descendant2_tags_wbr': <tf.Tensor 'DecodeCSV:433' shape=() dtype=float32>,
#  'descendant2_tags_wsj': <tf.Tensor 'DecodeCSV:434' shape=() dtype=float32>,
#  'descendant3_tags_a': <tf.Tensor 'DecodeCSV:435' shape=() dtype=float32>,
#  'descendant3_tags_abbr': <tf.Tensor 'DecodeCSV:436' shape=() dtype=float32>,
#  'descendant3_tags_acronym': <tf.Tensor 'DecodeCSV:437' shape=() dtype=float32>,
#  'descendant3_tags_address': <tf.Tensor 'DecodeCSV:438' shape=() dtype=float32>,
#  'descendant3_tags_ahref': <tf.Tensor 'DecodeCSV:439' shape=() dtype=float32>,
#  'descendant3_tags_align': <tf.Tensor 'DecodeCSV:440' shape=() dtype=float32>,
#  'descendant3_tags_applet': <tf.Tensor 'DecodeCSV:441' shape=() dtype=float32>,
#  'descendant3_tags_area': <tf.Tensor 'DecodeCSV:442' shape=() dtype=float32>,
#  'descendant3_tags_artbody': <tf.Tensor 'DecodeCSV:443' shape=() dtype=float32>,
#  'descendant3_tags_arybhatt': <tf.Tensor 'DecodeCSV:444' shape=() dtype=float32>,
#  'descendant3_tags_asc': <tf.Tensor 'DecodeCSV:445' shape=() dtype=float32>,
#  'descendant3_tags_author': <tf.Tensor 'DecodeCSV:446' shape=() dtype=float32>,
#  'descendant3_tags_b': <tf.Tensor 'DecodeCSV:447' shape=() dtype=float32>,
#  'descendant3_tags_base': <tf.Tensor 'DecodeCSV:448' shape=() dtype=float32>,
#  'descendant3_tags_basefont': <tf.Tensor 'DecodeCSV:449' shape=() dtype=float32>,
#  'descendant3_tags_be': <tf.Tensor 'DecodeCSV:450' shape=() dtype=float32>,
#  'descendant3_tags_beginlock': <tf.Tensor 'DecodeCSV:451' shape=() dtype=float32>,
#  'descendant3_tags_bgsound': <tf.Tensor 'DecodeCSV:452' shape=() dtype=float32>,
#  'descendant3_tags_big': <tf.Tensor 'DecodeCSV:453' shape=() dtype=float32>,
#  'descendant3_tags_blink': <tf.Tensor 'DecodeCSV:454' shape=() dtype=float32>,
#  'descendant3_tags_blockqoute': <tf.Tensor 'DecodeCSV:455' shape=() dtype=float32>,
#  'descendant3_tags_blockquote': <tf.Tensor 'DecodeCSV:456' shape=() dtype=float32>,
#  'descendant3_tags_body': <tf.Tensor 'DecodeCSV:457' shape=() dtype=float32>,
#  'descendant3_tags_br': <tf.Tensor 'DecodeCSV:458' shape=() dtype=float32>,
#  'descendant3_tags_button': <tf.Tensor 'DecodeCSV:459' shape=() dtype=float32>,
#  'descendant3_tags_caption': <tf.Tensor 'DecodeCSV:460' shape=() dtype=float32>,
#  'descendant3_tags_center': <tf.Tensor 'DecodeCSV:461' shape=() dtype=float32>,
#  'descendant3_tags_cite': <tf.Tensor 'DecodeCSV:462' shape=() dtype=float32>,
#  'descendant3_tags_city': <tf.Tensor 'DecodeCSV:463' shape=() dtype=float32>,
#  'descendant3_tags_code': <tf.Tensor 'DecodeCSV:464' shape=() dtype=float32>,
#  'descendant3_tags_col': <tf.Tensor 'DecodeCSV:465' shape=() dtype=float32>,
#  'descendant3_tags_colgroup': <tf.Tensor 'DecodeCSV:466' shape=() dtype=float32>,
#  'descendant3_tags_companyquotes': <tf.Tensor 'DecodeCSV:467' shape=() dtype=float32>,
#  'descendant3_tags_container': <tf.Tensor 'DecodeCSV:468' shape=() dtype=float32>,
#  'descendant3_tags_content': <tf.Tensor 'DecodeCSV:469' shape=() dtype=float32>,
#  'descendant3_tags_content_area': <tf.Tensor 'DecodeCSV:470' shape=() dtype=float32>,
#  'descendant3_tags_content_footer': <tf.Tensor 'DecodeCSV:471' shape=() dtype=float32>,
#  'descendant3_tags_country-region': <tf.Tensor 'DecodeCSV:472' shape=() dtype=float32>,
#  'descendant3_tags_csaction': <tf.Tensor 'DecodeCSV:473' shape=() dtype=float32>,
#  'descendant3_tags_csactiondict': <tf.Tensor 'DecodeCSV:474' shape=() dtype=float32>,
#  'descendant3_tags_csactions': <tf.Tensor 'DecodeCSV:475' shape=() dtype=float32>,
#  'descendant3_tags_csimport': <tf.Tensor 'DecodeCSV:476' shape=() dtype=float32>,
#  'descendant3_tags_csobj': <tf.Tensor 'DecodeCSV:477' shape=() dtype=float32>,
#  'descendant3_tags_csscriptdict': <tf.Tensor 'DecodeCSV:478' shape=() dtype=float32>,
#  'descendant3_tags_cut': <tf.Tensor 'DecodeCSV:479' shape=() dtype=float32>,
#  'descendant3_tags_dd': <tf.Tensor 'DecodeCSV:480' shape=() dtype=float32>,
#  'descendant3_tags_deadilnk': <tf.Tensor 'DecodeCSV:481' shape=() dtype=float32>,
#  'descendant3_tags_defanged_meta': <tf.Tensor 'DecodeCSV:482' shape=() dtype=float32>,
#  'descendant3_tags_del': <tf.Tensor 'DecodeCSV:483' shape=() dtype=float32>,
#  'descendant3_tags_dfn': <tf.Tensor 'DecodeCSV:484' shape=() dtype=float32>,
#  'descendant3_tags_dir': <tf.Tensor 'DecodeCSV:485' shape=() dtype=float32>,
#  'descendant3_tags_displayname': <tf.Tensor 'DecodeCSV:486' shape=() dtype=float32>,
#  'descendant3_tags_div': <tf.Tensor 'DecodeCSV:487' shape=() dtype=float32>,
#  'descendant3_tags_dl': <tf.Tensor 'DecodeCSV:488' shape=() dtype=float32>,
#  'descendant3_tags_dnt': <tf.Tensor 'DecodeCSV:489' shape=() dtype=float32>,
#  'descendant3_tags_dt': <tf.Tensor 'DecodeCSV:490' shape=() dtype=float32>,
#  'descendant3_tags_em': <tf.Tensor 'DecodeCSV:491' shape=() dtype=float32>,
#  'descendant3_tags_embed': <tf.Tensor 'DecodeCSV:492' shape=() dtype=float32>,
#  'descendant3_tags_end': <tf.Tensor 'DecodeCSV:493' shape=() dtype=float32>,
#  'descendant3_tags_endlock': <tf.Tensor 'DecodeCSV:494' shape=() dtype=float32>,
#  'descendant3_tags_epabreadcrumbs': <tf.Tensor 'DecodeCSV:495' shape=() dtype=float32>,
#  'descendant3_tags_epadateurl': <tf.Tensor 'DecodeCSV:496' shape=() dtype=float32>,
#  'descendant3_tags_epasidebar': <tf.Tensor 'DecodeCSV:497' shape=() dtype=float32>,
#  'descendant3_tags_f': <tf.Tensor 'DecodeCSV:498' shape=() dtype=float32>,
#  'descendant3_tags_fieldset': <tf.Tensor 'DecodeCSV:499' shape=() dtype=float32>,
#  'descendant3_tags_font': <tf.Tensor 'DecodeCSV:500' shape=() dtype=float32>,
#  'descendant3_tags_form': <tf.Tensor 'DecodeCSV:501' shape=() dtype=float32>,
#  'descendant3_tags_formulas': <tf.Tensor 'DecodeCSV:502' shape=() dtype=float32>,
#  'descendant3_tags_garden01': <tf.Tensor 'DecodeCSV:503' shape=() dtype=float32>,
#  'descendant3_tags_gc3': <tf.Tensor 'DecodeCSV:504' shape=() dtype=float32>,
#  'descendant3_tags_h1': <tf.Tensor 'DecodeCSV:505' shape=() dtype=float32>,
#  'descendant3_tags_h2': <tf.Tensor 'DecodeCSV:506' shape=() dtype=float32>,
#  'descendant3_tags_h3': <tf.Tensor 'DecodeCSV:507' shape=() dtype=float32>,
#  'descendant3_tags_h4': <tf.Tensor 'DecodeCSV:508' shape=() dtype=float32>,
#  'descendant3_tags_h5': <tf.Tensor 'DecodeCSV:509' shape=() dtype=float32>,
#  'descendant3_tags_h6': <tf.Tensor 'DecodeCSV:510' shape=() dtype=float32>,
#  'descendant3_tags_h7': <tf.Tensor 'DecodeCSV:511' shape=() dtype=float32>,
#  'descendant3_tags_header': <tf.Tensor 'DecodeCSV:512' shape=() dtype=float32>,
#  'descendant3_tags_headline': <tf.Tensor 'DecodeCSV:513' shape=() dtype=float32>,
#  'descendant3_tags_hp': <tf.Tensor 'DecodeCSV:514' shape=() dtype=float32>,
#  'descendant3_tags_hr': <tf.Tensor 'DecodeCSV:515' shape=() dtype=float32>,
#  'descendant3_tags_html_comment': <tf.Tensor 'DecodeCSV:516' shape=() dtype=float32>,
#  'descendant3_tags_http-equiv': <tf.Tensor 'DecodeCSV:517' shape=() dtype=float32>,
#  'descendant3_tags_http:': <tf.Tensor 'DecodeCSV:518' shape=() dtype=float32>,
#  'descendant3_tags_i': <tf.Tensor 'DecodeCSV:519' shape=() dtype=float32>,
#  'descendant3_tags_id': <tf.Tensor 'DecodeCSV:520' shape=() dtype=float32>,
#  'descendant3_tags_if': <tf.Tensor 'DecodeCSV:521' shape=() dtype=float32>,
#  'descendant3_tags_iframe': <tf.Tensor 'DecodeCSV:522' shape=() dtype=float32>,
#  'descendant3_tags_ilayer': <tf.Tensor 'DecodeCSV:523' shape=() dtype=float32>,
#  'descendant3_tags_image': <tf.Tensor 'DecodeCSV:524' shape=() dtype=float32>,
#  'descendant3_tags_imagedata': <tf.Tensor 'DecodeCSV:525' shape=() dtype=float32>,
#  'descendant3_tags_img': <tf.Tensor 'DecodeCSV:526' shape=() dtype=float32>,
#  'descendant3_tags_inactivescript': <tf.Tensor 'DecodeCSV:527' shape=() dtype=float32>,
#  'descendant3_tags_input': <tf.Tensor 'DecodeCSV:528' shape=() dtype=float32>,
#  'descendant3_tags_intl_links': <tf.Tensor 'DecodeCSV:529' shape=() dtype=float32>,
#  'descendant3_tags_l': <tf.Tensor 'DecodeCSV:530' shape=() dtype=float32>,
#  'descendant3_tags_l1': <tf.Tensor 'DecodeCSV:531' shape=() dtype=float32>,
#  'descendant3_tags_l10': <tf.Tensor 'DecodeCSV:532' shape=() dtype=float32>,
#  'descendant3_tags_l11': <tf.Tensor 'DecodeCSV:533' shape=() dtype=float32>,
#  'descendant3_tags_l12': <tf.Tensor 'DecodeCSV:534' shape=() dtype=float32>,
#  'descendant3_tags_l2': <tf.Tensor 'DecodeCSV:535' shape=() dtype=float32>,
#  'descendant3_tags_l3': <tf.Tensor 'DecodeCSV:536' shape=() dtype=float32>,
#  'descendant3_tags_l4': <tf.Tensor 'DecodeCSV:537' shape=() dtype=float32>,
#  'descendant3_tags_l5': <tf.Tensor 'DecodeCSV:538' shape=() dtype=float32>,
#  'descendant3_tags_l6': <tf.Tensor 'DecodeCSV:539' shape=() dtype=float32>,
#  'descendant3_tags_l7': <tf.Tensor 'DecodeCSV:540' shape=() dtype=float32>,
#  'descendant3_tags_l8': <tf.Tensor 'DecodeCSV:541' shape=() dtype=float32>,
#  'descendant3_tags_l9': <tf.Tensor 'DecodeCSV:542' shape=() dtype=float32>,
#  'descendant3_tags_label': <tf.Tensor 'DecodeCSV:543' shape=() dtype=float32>,
#  'descendant3_tags_layer': <tf.Tensor 'DecodeCSV:544' shape=() dtype=float32>,
#  'descendant3_tags_left': <tf.Tensor 'DecodeCSV:545' shape=() dtype=float32>,
#  'descendant3_tags_left_nav': <tf.Tensor 'DecodeCSV:546' shape=() dtype=float32>,
#  'descendant3_tags_legend': <tf.Tensor 'DecodeCSV:547' shape=() dtype=float32>,
#  'descendant3_tags_li': <tf.Tensor 'DecodeCSV:548' shape=() dtype=float32>,
#  'descendant3_tags_link': <tf.Tensor 'DecodeCSV:549' shape=() dtype=float32>,
#  'descendant3_tags_lock': <tf.Tensor 'DecodeCSV:550' shape=() dtype=float32>,
#  'descendant3_tags_lscontent': <tf.Tensor 'DecodeCSV:551' shape=() dtype=float32>,
#  'descendant3_tags_mainorarchivepage': <tf.Tensor 'DecodeCSV:552' shape=() dtype=float32>,
#  'descendant3_tags_map': <tf.Tensor 'DecodeCSV:553' shape=() dtype=float32>,
#  'descendant3_tags_marquee': <tf.Tensor 'DecodeCSV:554' shape=() dtype=float32>,
#  'descendant3_tags_menu': <tf.Tensor 'DecodeCSV:555' shape=() dtype=float32>,
#  'descendant3_tags_meta': <tf.Tensor 'DecodeCSV:556' shape=() dtype=float32>,
#  'descendant3_tags_newselement': <tf.Tensor 'DecodeCSV:557' shape=() dtype=float32>,
#  'descendant3_tags_nitf': <tf.Tensor 'DecodeCSV:558' shape=() dtype=float32>,
#  'descendant3_tags_nobr': <tf.Tensor 'DecodeCSV:559' shape=() dtype=float32>,
#  'descendant3_tags_noedit': <tf.Tensor 'DecodeCSV:560' shape=() dtype=float32>,
#  'descendant3_tags_noindex': <tf.Tensor 'DecodeCSV:561' shape=() dtype=float32>,
#  'descendant3_tags_nolayer': <tf.Tensor 'DecodeCSV:562' shape=() dtype=float32>,
#  'descendant3_tags_noscript': <tf.Tensor 'DecodeCSV:563' shape=() dtype=float32>,
#  'descendant3_tags_nr': <tf.Tensor 'DecodeCSV:564' shape=() dtype=float32>,
#  'descendant3_tags_object': <tf.Tensor 'DecodeCSV:565' shape=() dtype=float32>,
#  'descendant3_tags_ol': <tf.Tensor 'DecodeCSV:566' shape=() dtype=float32>,
#  'descendant3_tags_optgroup': <tf.Tensor 'DecodeCSV:567' shape=() dtype=float32>,
#  'descendant3_tags_option': <tf.Tensor 'DecodeCSV:568' shape=() dtype=float32>,
#  'descendant3_tags_p': <tf.Tensor 'DecodeCSV:569' shape=() dtype=float32>,
#  'descendant3_tags_page': <tf.Tensor 'DecodeCSV:570' shape=() dtype=float32>,
#  'descendant3_tags_param': <tf.Tensor 'DecodeCSV:571' shape=() dtype=float32>,
#  'descendant3_tags_path': <tf.Tensor 'DecodeCSV:572' shape=() dtype=float32>,
#  'descendant3_tags_place': <tf.Tensor 'DecodeCSV:573' shape=() dtype=float32>,
#  'descendant3_tags_placename': <tf.Tensor 'DecodeCSV:574' shape=() dtype=float32>,
#  'descendant3_tags_placetype': <tf.Tensor 'DecodeCSV:575' shape=() dtype=float32>,
#  'descendant3_tags_pre': <tf.Tensor 'DecodeCSV:576' shape=() dtype=float32>,
#  'descendant3_tags_promo': <tf.Tensor 'DecodeCSV:577' shape=() dtype=float32>,
#  'descendant3_tags_q': <tf.Tensor 'DecodeCSV:578' shape=() dtype=float32>,
#  'descendant3_tags_removeforprint': <tf.Tensor 'DecodeCSV:579' shape=() dtype=float32>,
#  'descendant3_tags_s': <tf.Tensor 'DecodeCSV:580' shape=() dtype=float32>,
#  'descendant3_tags_script': <tf.Tensor 'DecodeCSV:581' shape=() dtype=float32>,
#  'descendant3_tags_select': <tf.Tensor 'DecodeCSV:582' shape=() dtype=float32>,
#  'descendant3_tags_shape': <tf.Tensor 'DecodeCSV:583' shape=() dtype=float32>,
#  'descendant3_tags_shapetype': <tf.Tensor 'DecodeCSV:584' shape=() dtype=float32>,
#  'descendant3_tags_small': <tf.Tensor 'DecodeCSV:585' shape=() dtype=float32>,
#  'descendant3_tags_smarttagtype': <tf.Tensor 'DecodeCSV:586' shape=() dtype=float32>,
#  'descendant3_tags_smile': <tf.Tensor 'DecodeCSV:587' shape=() dtype=float32>,
#  'descendant3_tags_spacer': <tf.Tensor 'DecodeCSV:588' shape=() dtype=float32>,
#  'descendant3_tags_span': <tf.Tensor 'DecodeCSV:589' shape=() dtype=float32>,
#  'descendant3_tags_state': <tf.Tensor 'DecodeCSV:590' shape=() dtype=float32>,
#  'descendant3_tags_storysumm': <tf.Tensor 'DecodeCSV:591' shape=() dtype=float32>,
#  'descendant3_tags_stroke': <tf.Tensor 'DecodeCSV:592' shape=() dtype=float32>,
#  'descendant3_tags_strong': <tf.Tensor 'DecodeCSV:593' shape=() dtype=float32>,
#  'descendant3_tags_style': <tf.Tensor 'DecodeCSV:594' shape=() dtype=float32>,
#  'descendant3_tags_sub': <tf.Tensor 'DecodeCSV:595' shape=() dtype=float32>,
#  'descendant3_tags_subscribe': <tf.Tensor 'DecodeCSV:596' shape=() dtype=float32>,
#  'descendant3_tags_sup': <tf.Tensor 'DecodeCSV:597' shape=() dtype=float32>,
#  'descendant3_tags_table': <tf.Tensor 'DecodeCSV:598' shape=() dtype=float32>,
#  'descendant3_tags_tbody': <tf.Tensor 'DecodeCSV:599' shape=() dtype=float32>,
#  'descendant3_tags_td': <tf.Tensor 'DecodeCSV:600' shape=() dtype=float32>,
#  'descendant3_tags_textarea': <tf.Tensor 'DecodeCSV:601' shape=() dtype=float32>,
#  'descendant3_tags_textbox': <tf.Tensor 'DecodeCSV:602' shape=() dtype=float32>,
#  'descendant3_tags_th': <tf.Tensor 'DecodeCSV:603' shape=() dtype=float32>,
#  'descendant3_tags_thead': <tf.Tensor 'DecodeCSV:604' shape=() dtype=float32>,
#  'descendant3_tags_title': <tf.Tensor 'DecodeCSV:605' shape=() dtype=float32>,
#  'descendant3_tags_tr': <tf.Tensor 'DecodeCSV:606' shape=() dtype=float32>,
#  'descendant3_tags_tt': <tf.Tensor 'DecodeCSV:607' shape=() dtype=float32>,
# ...
#  'descendant5_tags_artbody': <tf.Tensor 'DecodeCSV:788' shape=() dtype=float32>,
#  'descendant5_tags_arybhatt': <tf.Tensor 'DecodeCSV:789' shape=() dtype=float32>,
#  'descendant5_tags_asc': <tf.Tensor 'DecodeCSV:790' shape=() dtype=float32>,
#  'descendant5_tags_b': <tf.Tensor 'DecodeCSV:791' shape=() dtype=float32>,
#  'descendant5_tags_base': <tf.Tensor 'DecodeCSV:792' shape=() dtype=float32>,
#  'descendant5_tags_basefont': <tf.Tensor 'DecodeCSV:793' shape=() dtype=float32>,
#  'descendant5_tags_be': <tf.Tensor 'DecodeCSV:794' shape=() dtype=float32>,
#  'descendant5_tags_big': <tf.Tensor 'DecodeCSV:795' shape=() dtype=float32>,
#  'descendant5_tags_blink': <tf.Tensor 'DecodeCSV:796' shape=() dtype=float32>,
#  'descendant5_tags_blockqoute': <tf.Tensor 'DecodeCSV:797' shape=() dtype=float32>,
#  'descendant5_tags_blockquote': <tf.Tensor 'DecodeCSV:798' shape=() dtype=float32>,
#  'descendant5_tags_body': <tf.Tensor 'DecodeCSV:799' shape=() dtype=float32>,
#  'descendant5_tags_br': <tf.Tensor 'DecodeCSV:800' shape=() dtype=float32>,
#  'descendant5_tags_button': <tf.Tensor 'DecodeCSV:801' shape=() dtype=float32>,
#  'descendant5_tags_caption': <tf.Tensor 'DecodeCSV:802' shape=() dtype=float32>,
#  'descendant5_tags_center': <tf.Tensor 'DecodeCSV:803' shape=() dtype=float32>,
#  'descendant5_tags_cite': <tf.Tensor 'DecodeCSV:804' shape=() dtype=float32>,
#  'descendant5_tags_city': <tf.Tensor 'DecodeCSV:805' shape=() dtype=float32>,
#  'descendant5_tags_code': <tf.Tensor 'DecodeCSV:806' shape=() dtype=float32>,
#  'descendant5_tags_col': <tf.Tensor 'DecodeCSV:807' shape=() dtype=float32>,
#  'descendant5_tags_colgroup': <tf.Tensor 'DecodeCSV:808' shape=() dtype=float32>,
#  'descendant5_tags_companyquotes': <tf.Tensor 'DecodeCSV:809' shape=() dtype=float32>,
#  'descendant5_tags_container': <tf.Tensor 'DecodeCSV:810' shape=() dtype=float32>,
#  'descendant5_tags_content': <tf.Tensor 'DecodeCSV:811' shape=() dtype=float32>,
#  'descendant5_tags_content_area': <tf.Tensor 'DecodeCSV:812' shape=() dtype=float32>,
#  'descendant5_tags_content_footer': <tf.Tensor 'DecodeCSV:813' shape=() dtype=float32>,
#  'descendant5_tags_country-region': <tf.Tensor 'DecodeCSV:814' shape=() dtype=float32>,
#  'descendant5_tags_csobj': <tf.Tensor 'DecodeCSV:815' shape=() dtype=float32>,
#  'descendant5_tags_cut': <tf.Tensor 'DecodeCSV:816' shape=() dtype=float32>,
#  'descendant5_tags_dd': <tf.Tensor 'DecodeCSV:817' shape=() dtype=float32>,
#  'descendant5_tags_deadilnk': <tf.Tensor 'DecodeCSV:818' shape=() dtype=float32>,
#  'descendant5_tags_del': <tf.Tensor 'DecodeCSV:819' shape=() dtype=float32>,
#  'descendant5_tags_dfn': <tf.Tensor 'DecodeCSV:820' shape=() dtype=float32>,
#  'descendant5_tags_dir': <tf.Tensor 'DecodeCSV:821' shape=() dtype=float32>,
#  'descendant5_tags_displayname': <tf.Tensor 'DecodeCSV:822' shape=() dtype=float32>,
#  'descendant5_tags_div': <tf.Tensor 'DecodeCSV:823' shape=() dtype=float32>,
#  'descendant5_tags_dl': <tf.Tensor 'DecodeCSV:824' shape=() dtype=float32>,
#  'descendant5_tags_dnt': <tf.Tensor 'DecodeCSV:825' shape=() dtype=float32>,
#  'descendant5_tags_dt': <tf.Tensor 'DecodeCSV:826' shape=() dtype=float32>,
#  'descendant5_tags_em': <tf.Tensor 'DecodeCSV:827' shape=() dtype=float32>,
#  'descendant5_tags_embed': <tf.Tensor 'DecodeCSV:828' shape=() dtype=float32>,
#  'descendant5_tags_epabreadcrumbs': <tf.Tensor 'DecodeCSV:829' shape=() dtype=float32>,
#  'descendant5_tags_epadateurl': <tf.Tensor 'DecodeCSV:830' shape=() dtype=float32>,
#  'descendant5_tags_epasidebar': <tf.Tensor 'DecodeCSV:831' shape=() dtype=float32>,
#  'descendant5_tags_f': <tf.Tensor 'DecodeCSV:832' shape=() dtype=float32>,
#  'descendant5_tags_fieldset': <tf.Tensor 'DecodeCSV:833' shape=() dtype=float32>,
#  'descendant5_tags_font': <tf.Tensor 'DecodeCSV:834' shape=() dtype=float32>,
#  'descendant5_tags_form': <tf.Tensor 'DecodeCSV:835' shape=() dtype=float32>,
#  'descendant5_tags_formulas': <tf.Tensor 'DecodeCSV:836' shape=() dtype=float32>,
#  'descendant5_tags_garden01': <tf.Tensor 'DecodeCSV:837' shape=() dtype=float32>,
#  'descendant5_tags_gc3': <tf.Tensor 'DecodeCSV:838' shape=() dtype=float32>,
#  'descendant5_tags_h1': <tf.Tensor 'DecodeCSV:839' shape=() dtype=float32>,
#  'descendant5_tags_h2': <tf.Tensor 'DecodeCSV:840' shape=() dtype=float32>,
#  'descendant5_tags_h3': <tf.Tensor 'DecodeCSV:841' shape=() dtype=float32>,
#  'descendant5_tags_h4': <tf.Tensor 'DecodeCSV:842' shape=() dtype=float32>,
#  'descendant5_tags_h5': <tf.Tensor 'DecodeCSV:843' shape=() dtype=float32>,
#  'descendant5_tags_h6': <tf.Tensor 'DecodeCSV:844' shape=() dtype=float32>,
#  'descendant5_tags_h7': <tf.Tensor 'DecodeCSV:845' shape=() dtype=float32>,
#  'descendant5_tags_header': <tf.Tensor 'DecodeCSV:846' shape=() dtype=float32>,
#  'descendant5_tags_headline': <tf.Tensor 'DecodeCSV:847' shape=() dtype=float32>,
#  'descendant5_tags_hr': <tf.Tensor 'DecodeCSV:848' shape=() dtype=float32>,
#  'descendant5_tags_html_comment': <tf.Tensor 'DecodeCSV:849' shape=() dtype=float32>,
#  'descendant5_tags_http:': <tf.Tensor 'DecodeCSV:850' shape=() dtype=float32>,
#  'descendant5_tags_i': <tf.Tensor 'DecodeCSV:851' shape=() dtype=float32>,
#  'descendant5_tags_id': <tf.Tensor 'DecodeCSV:852' shape=() dtype=float32>,
#  'descendant5_tags_if': <tf.Tensor 'DecodeCSV:853' shape=() dtype=float32>,
#  'descendant5_tags_iframe': <tf.Tensor 'DecodeCSV:854' shape=() dtype=float32>,
#  'descendant5_tags_ilayer': <tf.Tensor 'DecodeCSV:855' shape=() dtype=float32>,
#  'descendant5_tags_imagedata': <tf.Tensor 'DecodeCSV:856' shape=() dtype=float32>,
#  'descendant5_tags_img': <tf.Tensor 'DecodeCSV:857' shape=() dtype=float32>,
#  'descendant5_tags_inactivescript': <tf.Tensor 'DecodeCSV:858' shape=() dtype=float32>,
#  'descendant5_tags_input': <tf.Tensor 'DecodeCSV:859' shape=() dtype=float32>,
#  'descendant5_tags_intl_links': <tf.Tensor 'DecodeCSV:860' shape=() dtype=float32>,
#  'descendant5_tags_l': <tf.Tensor 'DecodeCSV:861' shape=() dtype=float32>,
#  'descendant5_tags_l1': <tf.Tensor 'DecodeCSV:862' shape=() dtype=float32>,
#  'descendant5_tags_l10': <tf.Tensor 'DecodeCSV:863' shape=() dtype=float32>,
#  'descendant5_tags_l11': <tf.Tensor 'DecodeCSV:864' shape=() dtype=float32>,
#  'descendant5_tags_l12': <tf.Tensor 'DecodeCSV:865' shape=() dtype=float32>,
#  'descendant5_tags_l2': <tf.Tensor 'DecodeCSV:866' shape=() dtype=float32>,
#  'descendant5_tags_l3': <tf.Tensor 'DecodeCSV:867' shape=() dtype=float32>,
#  'descendant5_tags_l4': <tf.Tensor 'DecodeCSV:868' shape=() dtype=float32>,
#  'descendant5_tags_l5': <tf.Tensor 'DecodeCSV:869' shape=() dtype=float32>,
#  'descendant5_tags_l6': <tf.Tensor 'DecodeCSV:870' shape=() dtype=float32>,
#  'descendant5_tags_l7': <tf.Tensor 'DecodeCSV:871' shape=() dtype=float32>,
#  'descendant5_tags_l8': <tf.Tensor 'DecodeCSV:872' shape=() dtype=float32>,
#  'descendant5_tags_l9': <tf.Tensor 'DecodeCSV:873' shape=() dtype=float32>,
#  'descendant5_tags_label': <tf.Tensor 'DecodeCSV:874' shape=() dtype=float32>,
#  'descendant5_tags_layer': <tf.Tensor 'DecodeCSV:875' shape=() dtype=float32>,
#  'descendant5_tags_left': <tf.Tensor 'DecodeCSV:876' shape=() dtype=float32>,
#  'descendant5_tags_left_nav': <tf.Tensor 'DecodeCSV:877' shape=() dtype=float32>,
#  'descendant5_tags_legend': <tf.Tensor 'DecodeCSV:878' shape=() dtype=float32>,
#  'descendant5_tags_li': <tf.Tensor 'DecodeCSV:879' shape=() dtype=float32>,
#  'descendant5_tags_link': <tf.Tensor 'DecodeCSV:880' shape=() dtype=float32>,
#  'descendant5_tags_lock': <tf.Tensor 'DecodeCSV:881' shape=() dtype=float32>,
#  'descendant5_tags_mainorarchivepage': <tf.Tensor 'DecodeCSV:882' shape=() dtype=float32>,
#  'descendant5_tags_map': <tf.Tensor 'DecodeCSV:883' shape=() dtype=float32>,
#  'descendant5_tags_marquee': <tf.Tensor 'DecodeCSV:884' shape=() dtype=float32>,
#  'descendant5_tags_menu': <tf.Tensor 'DecodeCSV:885' shape=() dtype=float32>,
#  'descendant5_tags_meta': <tf.Tensor 'DecodeCSV:886' shape=() dtype=float32>,
#  'descendant5_tags_newselement': <tf.Tensor 'DecodeCSV:887' shape=() dtype=float32>,
#  'descendant5_tags_nitf': <tf.Tensor 'DecodeCSV:888' shape=() dtype=float32>,
#  'descendant5_tags_nobr': <tf.Tensor 'DecodeCSV:889' shape=() dtype=float32>,
#  'descendant5_tags_noedit': <tf.Tensor 'DecodeCSV:890' shape=() dtype=float32>,
#  'descendant5_tags_noindex': <tf.Tensor 'DecodeCSV:891' shape=() dtype=float32>,
#  'descendant5_tags_nolayer': <tf.Tensor 'DecodeCSV:892' shape=() dtype=float32>,
#  'descendant5_tags_noscript': <tf.Tensor 'DecodeCSV:893' shape=() dtype=float32>,
#  'descendant5_tags_nr': <tf.Tensor 'DecodeCSV:894' shape=() dtype=float32>,
#  'descendant5_tags_object': <tf.Tensor 'DecodeCSV:895' shape=() dtype=float32>,
#  'descendant5_tags_ol': <tf.Tensor 'DecodeCSV:896' shape=() dtype=float32>,
#  'descendant5_tags_optgroup': <tf.Tensor 'DecodeCSV:897' shape=() dtype=float32>,
#  'descendant5_tags_option': <tf.Tensor 'DecodeCSV:898' shape=() dtype=float32>,
#  'descendant5_tags_p': <tf.Tensor 'DecodeCSV:899' shape=() dtype=float32>,
#  'descendant5_tags_param': <tf.Tensor 'DecodeCSV:900' shape=() dtype=float32>,
#  'descendant5_tags_path': <tf.Tensor 'DecodeCSV:901' shape=() dtype=float32>,
#  'descendant5_tags_place': <tf.Tensor 'DecodeCSV:902' shape=() dtype=float32>,
#  'descendant5_tags_placename': <tf.Tensor 'DecodeCSV:903' shape=() dtype=float32>,
#  'descendant5_tags_placetype': <tf.Tensor 'DecodeCSV:904' shape=() dtype=float32>,
#  'descendant5_tags_pre': <tf.Tensor 'DecodeCSV:905' shape=() dtype=float32>,
#  'descendant5_tags_promo': <tf.Tensor 'DecodeCSV:906' shape=() dtype=float32>,
#  'descendant5_tags_q': <tf.Tensor 'DecodeCSV:907' shape=() dtype=float32>,
#  'descendant5_tags_removeforprint': <tf.Tensor 'DecodeCSV:908' shape=() dtype=float32>,
#  'descendant5_tags_s': <tf.Tensor 'DecodeCSV:909' shape=() dtype=float32>,
#  'descendant5_tags_script': <tf.Tensor 'DecodeCSV:910' shape=() dtype=float32>,
#  'descendant5_tags_select': <tf.Tensor 'DecodeCSV:911' shape=() dtype=float32>,
#  'descendant5_tags_shape': <tf.Tensor 'DecodeCSV:912' shape=() dtype=float32>,
#  'descendant5_tags_shapetype': <tf.Tensor 'DecodeCSV:913' shape=() dtype=float32>,
#  'descendant5_tags_small': <tf.Tensor 'DecodeCSV:914' shape=() dtype=float32>,
#  'descendant5_tags_smile': <tf.Tensor 'DecodeCSV:915' shape=() dtype=float32>,
#  'descendant5_tags_spacer': <tf.Tensor 'DecodeCSV:916' shape=() dtype=float32>,
#  'descendant5_tags_span': <tf.Tensor 'DecodeCSV:917' shape=() dtype=float32>,
#  'descendant5_tags_state': <tf.Tensor 'DecodeCSV:918' shape=() dtype=float32>,
#  'descendant5_tags_storysumm': <tf.Tensor 'DecodeCSV:919' shape=() dtype=float32>,
#  'descendant5_tags_stroke': <tf.Tensor 'DecodeCSV:920' shape=() dtype=float32>,
#  'descendant5_tags_strong': <tf.Tensor 'DecodeCSV:921' shape=() dtype=float32>,
#  'descendant5_tags_style': <tf.Tensor 'DecodeCSV:922' shape=() dtype=float32>,
#  'descendant5_tags_sub': <tf.Tensor 'DecodeCSV:923' shape=() dtype=float32>,
#  'descendant5_tags_subscribe': <tf.Tensor 'DecodeCSV:924' shape=() dtype=float32>,
#  'descendant5_tags_sup': <tf.Tensor 'DecodeCSV:925' shape=() dtype=float32>,
#  'descendant5_tags_table': <tf.Tensor 'DecodeCSV:926' shape=() dtype=float32>,
#  'descendant5_tags_tbody': <tf.Tensor 'DecodeCSV:927' shape=() dtype=float32>,
#  'descendant5_tags_td': <tf.Tensor 'DecodeCSV:928' shape=() dtype=float32>,
#  'descendant5_tags_textarea': <tf.Tensor 'DecodeCSV:929' shape=() dtype=float32>,
#  'descendant5_tags_textbox': <tf.Tensor 'DecodeCSV:930' shape=() dtype=float32>,
#  'descendant5_tags_th': <tf.Tensor 'DecodeCSV:931' shape=() dtype=float32>,
#  'descendant5_tags_thead': <tf.Tensor 'DecodeCSV:932' shape=() dtype=float32>,
#  'descendant5_tags_title': <tf.Tensor 'DecodeCSV:933' shape=() dtype=float32>,
#  'descendant5_tags_tr': <tf.Tensor 'DecodeCSV:934' shape=() dtype=float32>,
#  'descendant5_tags_tt': <tf.Tensor 'DecodeCSV:935' shape=() dtype=float32>,
#  'descendant5_tags_u': <tf.Tensor 'DecodeCSV:936' shape=() dtype=float32>,
#  'descendant5_tags_ul': <tf.Tensor 'DecodeCSV:937' shape=() dtype=float32>,
#  'descendant5_tags_var': <tf.Tensor 'DecodeCSV:938' shape=() dtype=float32>,
#  'descendant5_tags_verdana': <tf.Tensor 'DecodeCSV:939' shape=() dtype=float32>,
#  'descendant5_tags_wbr': <tf.Tensor 'DecodeCSV:940' shape=() dtype=float32>,
#  'descendant5_tags_wsj': <tf.Tensor 'DecodeCSV:941' shape=() dtype=float32>,
#  'tag_html': <tf.Tensor 'DecodeCSV:942' shape=() dtype=float32>,
#  'tag_body': <tf.Tensor 'DecodeCSV:943' shape=() dtype=float32>,
#  'tag_text': <tf.Tensor 'DecodeCSV:944' shape=() dtype=float32>,
#  'tag_meta': <tf.Tensor 'DecodeCSV:945' shape=() dtype=float32>,
#  'tag_title': <tf.Tensor 'DecodeCSV:946' shape=() dtype=float32>,
#  'tag_table': <tf.Tensor 'DecodeCSV:947' shape=() dtype=float32>,
#  'tag_tr': <tf.Tensor 'DecodeCSV:948' shape=() dtype=float32>,
#  'tag_td': <tf.Tensor 'DecodeCSV:949' shape=() dtype=float32>,
#  'tag_img': <tf.Tensor 'DecodeCSV:950' shape=() dtype=float32>,
#  'tag_br': <tf.Tensor 'DecodeCSV:951' shape=() dtype=float32>,
#  'tag_font': <tf.Tensor 'DecodeCSV:952' shape=() dtype=float32>,
#  'tag_b': <tf.Tensor 'DecodeCSV:953' shape=() dtype=float32>,
#  'tag_a': <tf.Tensor 'DecodeCSV:954' shape=() dtype=float32>,
#  'tag_p': <tf.Tensor 'DecodeCSV:955' shape=() dtype=float32>,
#  'tag_base': <tf.Tensor 'DecodeCSV:956' shape=() dtype=float32>,
#  'tag_html_comment': <tf.Tensor 'DecodeCSV:957' shape=() dtype=float32>,
#  'tag_style': <tf.Tensor 'DecodeCSV:958' shape=() dtype=float32>,
#  'tag_h1': <tf.Tensor 'DecodeCSV:959' shape=() dtype=float32>,
#  'tag_script': <tf.Tensor 'DecodeCSV:960' shape=() dtype=float32>,
#  'tag_div': <tf.Tensor 'DecodeCSV:961' shape=() dtype=float32>,
#  'tag_center': <tf.Tensor 'DecodeCSV:962' shape=() dtype=float32>,
#  'tag_h2': <tf.Tensor 'DecodeCSV:963' shape=() dtype=float32>,
#  'tag_i': <tf.Tensor 'DecodeCSV:964' shape=() dtype=float32>,
#  'tag_ul': <tf.Tensor 'DecodeCSV:965' shape=() dtype=float32>,
#  'tag_li': <tf.Tensor 'DecodeCSV:966' shape=() dtype=float32>,
#  'tag_u': <tf.Tensor 'DecodeCSV:967' shape=() dtype=float32>,
#  'tag_ol': <tf.Tensor 'DecodeCSV:968' shape=() dtype=float32>,
#  'tag_strong': <tf.Tensor 'DecodeCSV:969' shape=() dtype=float32>,
#  'tag_noscript': <tf.Tensor 'DecodeCSV:970' shape=() dtype=float32>,
#  'tag_form': <tf.Tensor 'DecodeCSV:971' shape=() dtype=float32>,
#  'tag_input': <tf.Tensor 'DecodeCSV:972' shape=() dtype=float32>,
#  'tag_hr': <tf.Tensor 'DecodeCSV:973' shape=() dtype=float32>,
#  'tag_map': <tf.Tensor 'DecodeCSV:974' shape=() dtype=float32>,
#  'tag_dfn': <tf.Tensor 'DecodeCSV:975' shape=() dtype=float32>,
#  'tag_address': <tf.Tensor 'DecodeCSV:976' shape=() dtype=float32>,
#  'tag_span': <tf.Tensor 'DecodeCSV:977' shape=() dtype=float32>,
#  'tag_pre': <tf.Tensor 'DecodeCSV:978' shape=() dtype=float32>,
#  'tag_small': <tf.Tensor 'DecodeCSV:979' shape=() dtype=float32>,
#  'tag_em': <tf.Tensor 'DecodeCSV:980' shape=() dtype=float32>,
#  'tag_link': <tf.Tensor 'DecodeCSV:981' shape=() dtype=float32>,
#  'tag_h3': <tf.Tensor 'DecodeCSV:982' shape=() dtype=float32>,
#  'tag_textarea': <tf.Tensor 'DecodeCSV:983' shape=() dtype=float32>,
#  'tag_label': <tf.Tensor 'DecodeCSV:984' shape=() dtype=float32>,
#  'tag_h6': <tf.Tensor 'DecodeCSV:985' shape=() dtype=float32>,
#  'tag_sub': <tf.Tensor 'DecodeCSV:986' shape=() dtype=float32>,
#  'tag_sup': <tf.Tensor 'DecodeCSV:987' shape=() dtype=float32>,
#  'tag_h5': <tf.Tensor 'DecodeCSV:988' shape=() dtype=float32>,
#  'tag_h4': <tf.Tensor 'DecodeCSV:989' shape=() dtype=float32>,
#  'tag_th': <tf.Tensor 'DecodeCSV:990' shape=() dtype=float32>,
#  'tag_dir': <tf.Tensor 'DecodeCSV:991' shape=() dtype=float32>,
#  'tag_http:': <tf.Tensor 'DecodeCSV:992' shape=() dtype=float32>,
#  'tag_marquee': <tf.Tensor 'DecodeCSV:993' shape=() dtype=float32>,
#  'tag_blockquote': <tf.Tensor 'DecodeCSV:994' shape=() dtype=float32>,
#  'tag_area': <tf.Tensor 'DecodeCSV:995' shape=() dtype=float32>,
#  'tag_iframe': <tf.Tensor 'DecodeCSV:996' shape=() dtype=float32>,
#  'tag_select': <tf.Tensor 'DecodeCSV:997' shape=() dtype=float32>,
#  'tag_option': <tf.Tensor 'DecodeCSV:998' shape=() dtype=float32>,
#  'tag_newselement': <tf.Tensor 'DecodeCSV:999' shape=() dtype=float32>,
#  ...}

# %%
with tf.Session() as sess:
    # variables must be initialized otherwise it fails 
    sess.run(tf.local_variables_initializer())
    sess.run(tf.global_variables_initializer())
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)
    try:
        for step in range(10):
            if coord.should_stop():
                break
            print(sess.run([tens_dict['depth'], tens_dict['content_label']]))
    except Exception as e:
        # Report exceptions to the coordinator.
        coord.request_stop(e)
    finally:
        # Terminate as usual. It is safe to call `coord.request_stop()` twice.
        coord.request_stop()
        coord.join(threads)
# Out:
# [3.0, 0.0]
# [5.0, 0.0]
# [4.0, 0.0]
# [5.0, 1.0]
# [5.0, 1.0]
# [6.0, 0.0]
# [6.0, 1.0]
# [4.0, 0.0]
# [5.0, 1.0]
# [10.0, 0.0]
